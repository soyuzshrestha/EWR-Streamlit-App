# %%
import pandas as pd
import numpy as np
import os
import urllib
import warnings
warnings.filterwarnings('ignore')

# %%
flight_sch = pd.read_csv('Flight_Schedule.csv')
flight_ops = pd.read_csv('Aerobahn_operation.csv')

# %%
flight_sch.shape
# Out:
# (54869, 20)

# %%
flight_ops.shape
# Out:
# (53489, 22)

# %%
flight_sch = flight_sch.dropna()

# %%
flight_ops = flight_ops.dropna()

# %%
flight_ops.columns
# Out:
# Index(['Date', 'Military Hour', 'Minutes', 'Military Time', 'Flight Direction',
#        'PA Airport Code', 'Terminal Desc', 'Concourse Desc', 'Gate Desc',
#        'Non-PA Airport Code', 'Non-PA Airport Country Desc', 'State Desc',
#        'Marketing Airline Desc', 'Marketing Airline ICAO Code',
#        'Operating Airline Desc', 'Operating Airline ICAO Code', 'Call Sign',
#        'General Aircraft Desc', 'Variant Aircraft Desc',
#        'Variant Aircraft Code', 'Max Seats', 'Total Flights'],
#       dtype='object')

# %%
flight_sch.columns
# Out:
# Index(['Date', 'Military Time', 'Flight Direction', 'PA Airport Code',
#        'Terminal Desc', 'Non-PA Airport Code', 'Non-PA Airport Country Desc',
#        'International Domestic', 'State Desc', 'Marketing Airline Desc',
#        'Marketing Airline ICAO Code', 'Operating Airline Desc',
#        'Operating Airline ICAO Code', 'Flight Number', 'General Aircraft Desc',
#        'Variant Aircraft Desc', 'Variant Aircraft Code', 'Total Seats',
#        'Flight Distance', 'Total Flights'],
#       dtype='object')

# %%
flight_sch.columns = [x.replace(' ','_') for x in flight_sch.columns]

# %%
flight_sch.columns
# Out:
# Index(['Date', 'Military_Time', 'Flight_Direction', 'PA_Airport_Code',
#        'Terminal_Desc', 'Non-PA_Airport_Code', 'Non-PA_Airport_Country_Desc',
#        'International_Domestic', 'State_Desc', 'Marketing_Airline_Desc',
#        'Marketing_Airline_ICAO_Code', 'Operating_Airline_Desc',
#        'Operating_Airline_ICAO_Code', 'Flight_Number', 'General_Aircraft_Desc',
#        'Variant_Aircraft_Desc', 'Variant_Aircraft_Code', 'Total_Seats',
#        'Flight_Distance', 'Total_Flights'],
#       dtype='object')

# %%
flight_ops.columns = [x.replace(' ','_') for x in flight_ops.columns]

# %%
flight_ops.columns
# Out:
# Index(['Date', 'Military_Hour', 'Minutes', 'Military_Time', 'Flight_Direction',
#        'PA_Airport_Code', 'Terminal_Desc', 'Concourse_Desc', 'Gate_Desc',
#        'Non-PA_Airport_Code', 'Non-PA_Airport_Country_Desc', 'State_Desc',
#        'Marketing_Airline_Desc', 'Marketing_Airline_ICAO_Code',
#        'Operating_Airline_Desc', 'Operating_Airline_ICAO_Code', 'Call_Sign',
#        'General_Aircraft_Desc', 'Variant_Aircraft_Desc',
#        'Variant_Aircraft_Code', 'Max_Seats', 'Total_Flights'],
#       dtype='object')

# %%
flight_ops = flight_ops[flight_ops.Flight_Direction=='Departure']

# %%
flight_ops
# Out:
#              Date  Military_Hour  Minutes Military_Time Flight_Direction  \
# 1        1/1/2021            1.0      5.0      01:05:58        Departure
# 9        1/1/2021            6.0     24.0      06:24:24        Departure
# 10       1/1/2021            6.0     35.0      06:35:16        Departure
# 11       1/1/2021            6.0     37.0      06:37:56        Departure
# 13       1/1/2021            7.0     18.0      07:18:39        Departure
# ...           ...            ...      ...           ...              ...
# 53466  12/31/2021           20.0     47.0      20:47:22        Departure
# 53467  12/31/2021           20.0     58.0      20:58:57        Departure
# 53468  12/31/2021           21.0     10.0      21:10:21        Departure
# 53476  12/31/2021           21.0     54.0      21:54:53        Departure
# 53477  12/31/2021           22.0      2.0      22:02:10        Departure
#
#       PA_Airport_Code   Terminal_Desc Concourse_Desc Gate_Desc  \
# 1                 EWR  EWR-Terminal B  Concourse B-3       B61
# 9                 EWR  EWR-Terminal B  Concourse B-1      B41B
# 10                EWR  EWR-Terminal B  Concourse B-1       B45
# 11                EWR  EWR-Terminal B  Concourse B-1      B46B
# 13                EWR  EWR-Terminal B  Concourse B-1       B43
# ...               ...             ...            ...       ...
# 53466             EWR  EWR-Terminal B  Concourse B-1      B41A
# 53467             EWR  EWR-Terminal B  Concourse B-3       B62
# 53468             EWR  EWR-Terminal B  Concourse B-1      B41B
# 53476             EWR  EWR-Terminal B  Concourse B-2       B54
# 53477             EWR  EWR-Terminal B  Concourse B-2       B53
#
#       Non-PA_Airport_Code  ... Marketing_Airline_Desc  \
# 1                     SJU  ...        Spirit Airlines
# 9                     FLL  ...        Spirit Airlines
# 10                    DTW  ...        Delta Air Lines
# 11                    ATL  ...        Delta Air Lines
# 13                    ATL  ...        Spirit Airlines
# ...                   ...  ...                    ...
# 53466                 BNA  ...        Spirit Airlines
# 53467                 MUC  ...              Lufthansa
# 53468                 AUS  ...        Spirit Airlines
# 53476                 LHR  ...        British Airways
# 53477                 LFW  ...     Ethiopian Airlines
#
#       Marketing_Airline_ICAO_Code Operating_Airline_Desc  \
# 1                             NKS        Spirit Airlines
# 9                             NKS        Spirit Airlines
# 10                            DAL        Delta Air Lines
# 11                            DAL        Delta Air Lines
# 13                            NKS        Spirit Airlines
# ...                           ...                    ...
# 53466                         NKS        Spirit Airlines
# 53467                         DLH              Lufthansa
# 53468                         NKS        Spirit Airlines
# 53476                         BAW        British Airways
# 53477                         ETH     Ethiopian Airlines
#
#       Operating_Airline_ICAO_Code Call_Sign    General_Aircraft_Desc  \
# 1                             NKS   NKS1035  Airbus A318/319/320/321
# 9                             NKS    NKS521  Airbus A318/319/320/321
# 10                            DAL   DAL1646              Airbus A220
# 11                            DAL   DAL2060               Boeing 737
# 13                            NKS     NKS56  Airbus A318/319/320/321
# ...                           ...       ...                      ...
# 53466                         NKS   NKS1174  Airbus A318/319/320/321
# 53467                         DLH    DLH413              Airbus A350
# 53468                         NKS   NKS2309  Airbus A318/319/320/321
# 53476                         BAW    BAW188               Boeing 787
# 53477                         ETH    ETH509               Boeing 787
#
#       Variant_Aircraft_Desc Variant_Aircraft_Code Max_Seats Total_Flights
# 1               Airbus A321                  A321     185.0             1
# 9               Airbus A321                  A321     185.0             1
# 10          Airbus A220-100                   221     135.0             1
# 11           Boeing 737-800                   738     165.0             1
# 13              Airbus A320                  A320     150.0             1
# ...                     ...                   ...       ...           ...
# 53466        Airbus A320neo                   32N     165.0             1
# 53467       Airbus A350-900                   359     320.0             1
# 53468           Airbus A320                  A320     150.0             1
# 53476          Boeing 787-8                   788     242.0             1
# 53477          Boeing 787-8                   788     242.0             1
#
# [18913 rows x 22 columns]

# %%
flight_sch = flight_sch[flight_sch.Flight_Direction=='Departure']

# %%
flight_sch
# Out:
#              Date Military_Time Flight_Direction PA_Airport_Code  \
# 0        1/1/2021      00:59:00        Departure             EWR
# 8        1/1/2021      06:00:00        Departure             EWR
# 9        1/1/2021      06:00:00        Departure             EWR
# 10       1/1/2021      06:15:00        Departure             EWR
# 12       1/1/2021      07:00:00        Departure             EWR
# ...           ...           ...              ...             ...
# 54850  12/31/2021      21:50:00        Departure             EWR
# 54858  12/31/2021      23:10:00        Departure             EWR
# 54860  12/31/2021      23:25:00        Departure             EWR
# 54863  12/31/2021      23:55:00        Departure             EWR
# 54865  12/31/2021      23:59:00        Departure             EWR
#
#         Terminal_Desc Non-PA_Airport_Code Non-PA_Airport_Country_Desc  \
# 0      EWR-Terminal B                 SJU                         USA
# 8      EWR-Terminal B                 DTW                         USA
# 9      EWR-Terminal B                 FLL                         USA
# 10     EWR-Terminal B                 ATL                         USA
# 12     EWR-Terminal B                 RSW                         USA
# ...               ...                 ...                         ...
# 54850  EWR-Terminal B                 LHR              United Kingdom
# 54858  EWR-Terminal B                 STI          Dominican Republic
# 54860  EWR-Terminal B                 ORY                      France
# 54863  EWR-Terminal B                 ATH                      Greece
# 54865  EWR-Terminal B                 SDQ          Dominican Republic
#
#       International_Domestic     State_Desc Marketing_Airline_Desc  \
# 0                   Domestic    Puerto Rico        Spirit Airlines
# 8                   Domestic       Michigan        Delta Air Lines
# 9                   Domestic        Florida        Spirit Airlines
# 10                  Domestic        Georgia        Delta Air Lines
# 12                  Domestic        Florida        Spirit Airlines
# ...                      ...            ...                    ...
# 54850          International  International        British Airways
# 54858          International  International        JetBlue Airways
# 54860          International  International             French Bee
# 54863          International  International               Emirates
# 54865          International  International        JetBlue Airways
#
#       Marketing_Airline_ICAO_Code Operating_Airline_Desc  \
# 0                             NKS        Spirit Airlines
# 8                             DAL        Delta Air Lines
# 9                             NKS        Spirit Airlines
# 10                            DAL        Delta Air Lines
# 12                            NKS        Spirit Airlines
# ...                           ...                    ...
# 54850                         BAW        British Airways
# 54858                         JBU        JetBlue Airways
# 54860                         FBU             French Bee
# 54863                         UAE               Emirates
# 54865                         JBU        JetBlue Airways
#
#       Operating_Airline_ICAO_Code  Flight_Number    General_Aircraft_Desc  \
# 0                             NKS         1035.0  Airbus A318/319/320/321
# 8                             DAL         1646.0              Airbus A220
# 9                             NKS          521.0  Airbus A318/319/320/321
# 10                            DAL         2060.0               Boeing 737
# 12                            NKS         1013.0  Airbus A318/319/320/321
# ...                           ...            ...                      ...
# 54850                         BAW          188.0               Boeing 787
# 54858                         JBU         1293.0  Airbus A318/319/320/321
# 54860                         FBU          721.0              Airbus A350
# 54863                         UAE          210.0               Boeing 777
# 54865                         JBU          403.0  Airbus A318/319/320/321
#
#          Variant_Aircraft_Desc Variant_Aircraft_Code Total_Seats  \
# 0      Airbus A321 (Sharklets)                   32B         228
# 8              Airbus A220-100                   221         109
# 9      Airbus A321 (Sharklets)                   32B         228
# 10              Boeing 737-800                   738         160
# 12     Airbus A320 (Sharklets)                   32A         182
# ...                        ...                   ...         ...
# 54850             Boeing 787-8                   788         214
# 54858              Airbus A320                   320         162
# 54860          Airbus A350-900                   359         411
# 54863         Boeing 777-300ER                   77W         354
# 54865              Airbus A320                   320         162
#
#       Flight_Distance Total_Flights
# 0               1,608             1
# 8                 488             1
# 9               1,065             1
# 10                746             1
# 12              1,068             1
# ...               ...           ...
# 54850           3,465             1
# 54858           1,476             1
# 54860           3,648             1
# 54863           4,948             1
# 54865           1,557             1
#
# [20095 rows x 20 columns]

# %%
(flight_sch['Date'].min(), flight_sch['Date'].max())
# Out:
# ('1/1/2021', '9/9/2021')

# %%
(flight_ops['Date'].min(), flight_ops['Date'].max())
# Out:
# ('1/1/2021', '9/9/2021')

# %%
flight_ops.shape
# Out:
# (18913, 22)

# %%
flight_sch.shape
# Out:
# (20095, 20)

# %%
flight_ops ['Actual_Departure'] = pd.to_datetime(flight_ops ['Military_Time'])

# %%
flight_sch ['Actual_Scheduled'] =pd.to_datetime(flight_sch ['Military_Time'])

# %%
flightDataMerge = pd.merge(flight_sch,flight_ops, how='outer')

# %%
flightDataMerge.shape
# Out:
# (39008, 28)

# %%
flightDataMerge ['Flight_Delay'] = flight_sch ['Actual_Scheduled'] - flight_ops ['Actual_Departure']

# %%
flightDataMerge
# Out:
#              Date Military_Time Flight_Direction PA_Airport_Code  \
# 0        1/1/2021      00:59:00        Departure             EWR
# 1        1/1/2021      06:00:00        Departure             EWR
# 2        1/1/2021      06:00:00        Departure             EWR
# 3        1/1/2021      06:15:00        Departure             EWR
# 4        1/1/2021      07:00:00        Departure             EWR
# ...           ...           ...              ...             ...
# 39003  12/31/2021      20:47:22        Departure             EWR
# 39004  12/31/2021      20:58:57        Departure             EWR
# 39005  12/31/2021      21:10:21        Departure             EWR
# 39006  12/31/2021      21:54:53        Departure             EWR
# 39007  12/31/2021      22:02:10        Departure             EWR
#
#         Terminal_Desc Non-PA_Airport_Code Non-PA_Airport_Country_Desc  \
# 0      EWR-Terminal B                 SJU                         USA
# 1      EWR-Terminal B                 DTW                         USA
# 2      EWR-Terminal B                 FLL                         USA
# 3      EWR-Terminal B                 ATL                         USA
# 4      EWR-Terminal B                 RSW                         USA
# ...               ...                 ...                         ...
# 39003  EWR-Terminal B                 BNA                         USA
# 39004  EWR-Terminal B                 MUC                     Germany
# 39005  EWR-Terminal B                 AUS                         USA
# 39006  EWR-Terminal B                 LHR              United Kingdom
# 39007  EWR-Terminal B                 LFW                        Togo
#
#       International_Domestic     State_Desc Marketing_Airline_Desc  ...  \
# 0                   Domestic    Puerto Rico        Spirit Airlines  ...
# 1                   Domestic       Michigan        Delta Air Lines  ...
# 2                   Domestic        Florida        Spirit Airlines  ...
# 3                   Domestic        Georgia        Delta Air Lines  ...
# 4                   Domestic        Florida        Spirit Airlines  ...
# ...                      ...            ...                    ...  ...
# 39003                    NaN      Tennessee        Spirit Airlines  ...
# 39004                    NaN  International              Lufthansa  ...
# 39005                    NaN          Texas        Spirit Airlines  ...
# 39006                    NaN  International        British Airways  ...
# 39007                    NaN  International     Ethiopian Airlines  ...
#
#       Total_Flights    Actual_Scheduled Military_Hour  Minutes Concourse_Desc  \
# 0                 1 2022-04-07 00:59:00           NaN      NaN            NaN
# 1                 1 2022-04-07 06:00:00           NaN      NaN            NaN
# 2                 1 2022-04-07 06:00:00           NaN      NaN            NaN
# 3                 1 2022-04-07 06:15:00           NaN      NaN            NaN
# 4                 1 2022-04-07 07:00:00           NaN      NaN            NaN
# ...             ...                 ...           ...      ...            ...
# 39003             1                 NaT          20.0     47.0  Concourse B-1
# 39004             1                 NaT          20.0     58.0  Concourse B-3
# 39005             1                 NaT          21.0     10.0  Concourse B-1
# 39006             1                 NaT          21.0     54.0  Concourse B-2
# 39007             1                 NaT          22.0      2.0  Concourse B-2
#
#       Gate_Desc Call_Sign Max_Seats    Actual_Departure    Flight_Delay
# 0           NaN       NaN       NaN                 NaT             NaT
# 1           NaN       NaN       NaN                 NaT             NaT
# 2           NaN       NaN       NaN                 NaT             NaT
# 3           NaN       NaN       NaN                 NaT             NaT
# 4           NaN       NaN       NaN                 NaT             NaT
# ...         ...       ...       ...                 ...             ...
# 39003      B41A   NKS1174     165.0 2022-04-07 20:47:22             NaT
# 39004       B62    DLH413     320.0 2022-04-07 20:58:57 0 days 04:16:28
# 39005      B41B   NKS2309     150.0 2022-04-07 21:10:21             NaT
# 39006       B54    BAW188     242.0 2022-04-07 21:54:53             NaT
# 39007       B53    ETH509     242.0 2022-04-07 22:02:10             NaT
#
# [39008 rows x 29 columns]
