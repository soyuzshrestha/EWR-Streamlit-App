# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## Load the data and recast variable types

# %%
fsched = pd.read_csv(r"C:\Users\Gabriel\OneDrive\CUSP\Spring 2022 Classes\Capstone\Data\Flight Schedule Detailed CUSP Export.csv")
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (17,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
brd = pd.read_excel(r'C:\Users\Gabriel\OneDrive\CUSP\Spring 2022 Classes\Capstone\Data\EWR_Data_Sept_2021.xlsx', sheet_name='EWR_Data_Sept_2021')

# %%
fsched.tail()
# Out:
#                                                     Date Military Time  \
# 54864                                         12/31/2021      23:59:00
# 54865                                         12/31/2021      23:59:00
# 54866                                              Total           NaN
# 54867                                                NaN           NaN
# 54868  Applied filters:\nDate 1/1/2021 - 12/31/2021\n...           NaN
#
#       Flight Direction PA Airport Code   Terminal Desc Non-PA Airport Code  \
# 54864          Arrival             EWR  EWR-Terminal B                 SDQ
# 54865        Departure             EWR  EWR-Terminal B                 SDQ
# 54866              NaN             NaN             NaN                 NaN
# 54867              NaN             NaN             NaN                 NaN
# 54868              NaN             NaN             NaN                 NaN
#
#       Non-PA Airport Country Desc International Domestic     State Desc  \
# 54864          Dominican Republic          International  International
# 54865          Dominican Republic          International  International
# 54866                         NaN                    NaN            NaN
# 54867                         NaN                    NaN            NaN
# 54868                         NaN                    NaN            NaN
#
#       Marketing Airline Desc Marketing Airline ICAO Code  \
# 54864        JetBlue Airways                         JBU
# 54865        JetBlue Airways                         JBU
# 54866                    NaN                         NaN
# 54867                    NaN                         NaN
# 54868                    NaN                         NaN
#
#       Operating Airline Desc Operating Airline ICAO Code  Flight Number  \
# 54864        JetBlue Airways                         JBU          604.0
# 54865        JetBlue Airways                         JBU          403.0
# 54866                    NaN                         NaN            NaN
# 54867                    NaN                         NaN            NaN
# 54868                    NaN                         NaN            NaN
#
#          General Aircraft Desc Variant Aircraft Desc Variant Aircraft Code  \
# 54864  Airbus A318/319/320/321           Airbus A320                   320
# 54865  Airbus A318/319/320/321           Airbus A320                   320
# 54866                      NaN                   NaN                   NaN
# 54867                      NaN                   NaN                   NaN
# 54868                      NaN                   NaN                   NaN
#
#       Total Seats Flight Distance Total Flights
# 54864         162           1,557             1
# 54865         162           1,557             1
# 54866  10,328,889             NaN        54,878
# 54867         NaN             NaN           NaN
# 54868         NaN             NaN           NaN

# %%
fsched.dtypes
# Out:
# Date                            object
# Military Time                   object
# Flight Direction                object
# PA Airport Code                 object
# Terminal Desc                   object
# Non-PA Airport Code             object
# Non-PA Airport Country Desc     object
# International Domestic          object
# State Desc                      object
# Marketing Airline Desc          object
# Marketing Airline ICAO Code     object
# Operating Airline Desc          object
# Operating Airline ICAO Code     object
# Flight Number                  float64
# General Aircraft Desc           object
# Variant Aircraft Desc           object
# Variant Aircraft Code           object
# Total Seats                     object
# Flight Distance                 object
# Total Flights                   object
# dtype: object

# %%
#remove last 3 rows of fsched because they contain column totals
fsched = fsched.iloc[:-3,:]

# %%
#date conversions, create new date columns
fsched['datt'] = pd.to_datetime(fsched['Date'] + ' ' + fsched['Military Time'])
fsched.Date = fsched.datt.dt.date
fsched['month'] = fsched.datt.dt.month
fsched['year'] = fsched.datt.dt.year

# %%
#create dat period columns
fsched['dayperiod'] = 0
for i in fsched.index:
    if fsched.loc[i,'datt'].hour in [6,7,8,9,10,11,12]:
        fsched.loc[i,'dayperiod'] = 'morning'
    elif fsched.loc[i,'datt'].hour in [13,14,15,16,17]:
        fsched.loc[i,'dayperiod'] = 'afternoon'
    elif fsched.loc[i,'datt'].hour in[18,19,20,21,22]:
        fsched.loc[i,'dayperiod'] = 'evening'
    elif fsched.loc[i,'datt'].hour in[23,0,1,2,3,4,5]:
        fsched.loc[i,'dayperiod'] = 'overnight'

fsched.head()
# Out:
#          Date Military Time Flight Direction PA Airport Code   Terminal Desc  \
# 0  2021-01-01      00:59:00        Departure             EWR  EWR-Terminal B
# 1  2021-01-01      01:29:00          Arrival             EWR  EWR-Terminal B
# 2  2021-01-01      04:25:00          Arrival             EWR  EWR-Terminal B
# 3  2021-01-01      04:45:00          Arrival             EWR  EWR-Terminal B
# 4  2021-01-01      05:30:00          Arrival             EWR  EWR-Terminal B
#
#   Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 0                 SJU                         USA               Domestic
# 1                 STI          Dominican Republic          International
# 2                 DEL                       India          International
# 3                 TLV                      Israel          International
# 4                 SAL                 El Salvador          International
#
#       State Desc Marketing Airline Desc Marketing Airline ICAO Code  \
# 0    Puerto Rico        Spirit Airlines                         NKS
# 1  International        JetBlue Airways                         JBU
# 2  International        United Airlines                         UAL
# 3  International        United Airlines                         UAL
# 4  International        United Airlines                         UAL
#
#   Operating Airline Desc Operating Airline ICAO Code  Flight Number  \
# 0        Spirit Airlines                         NKS         1035.0
# 1        JetBlue Airways                         JBU         1494.0
# 2        United Airlines                         UAL          802.0
# 3        United Airlines                         UAL           91.0
# 4        United Airlines                         UAL          341.0
#
#      General Aircraft Desc    Variant Aircraft Desc Variant Aircraft Code  \
# 0  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
# 1  Airbus A318/319/320/321              Airbus A321                   321
# 2               Boeing 777         Boeing 777-300ER                   77W
# 3               Boeing 787            Boeing 787-10                   781
# 4               Boeing 737           Boeing 737-900                   739
#
#   Total Seats Flight Distance Total Flights                datt  month  year  \
# 0         228           1,608             1 2021-01-01 00:59:00      1  2021
# 1         200           1,476             1 2021-01-01 01:29:00      1  2021
# 2         350           7,323             1 2021-01-01 04:25:00      1  2021
# 3         318           5,692             1 2021-01-01 04:45:00      1  2021
# 4         179           2,067             1 2021-01-01 05:30:00      1  2021
#
#    dayperiod
# 0  overnight
# 1  overnight
# 2  overnight
# 3  overnight
# 4  overnight

# %%
#numeric conversions
fsched['Total Seats'] = pd.to_numeric(fsched['Total Seats'])
fsched['Total Flights'] = pd.to_numeric(fsched['Total Flights'])
fsched['Flight Distance'] = fsched['Flight Distance'].str.replace(',', '').astype(float)

# %%
brd.head()
# Out:
#                                      ID  \
# 0  9B25B853-96B0-477B-A57D-00000FD957E0
# 1  7EB30923-789D-4154-98C6-00001F18CD27
# 2  1826AF57-3129-4355-9DEF-000058C854B7
# 3  EF168078-B7C3-4BCF-A8C2-0000A1142BA4
# 4  28D1C99A-40D5-4A40-9381-0000A7373B6F
#
#                                   HASH_DATA       EVENT_LOGTIME  \
# 0  BFE97412EC0C9F94B91CD25F77E5004DE15F0248 2021-09-28 05:45:45
# 1  61D727C12F09B1FD803E5614E3EDD81B9D6CA217 2021-09-26 16:04:55
# 2  A7E458694C3A1E2A0AB99D535538F8F50B621479 2021-09-19 20:41:14
# 3  96D0CEC3B0DEA035F491F369E24380D2975C54A8 2021-09-12 18:08:49
# 4  0F7F8061D3461E0D144933171EE09C6720ECDE8B 2021-09-10 04:56:43
#
#    LOCATION_POINT WORKSTATION  RTS_DATA  RTS_ENQUEUED  PROK  TS  \
# 0               1  EWRBAKB018       NaN           NaN   NaN NaN
# 1               1  EWRBAKB001       NaN           NaN   NaN NaN
# 2               1  EWRBCKB087       NaN           NaN   NaN NaN
# 3               1  EWRBCKB097       NaN           NaN   NaN NaN
# 4               1  EWRBAKB005       NaN           NaN   NaN NaN
#
#         STAGING_TIMESTAMP  EVENT_TYPE  LEG     PNR FROM_AIRPORT_CODE  \
# 0 2021-09-28 09:46:50.107  Print_BCBP    1  FM6RPE               LAS
# 1 2021-09-26 20:04:50.247  Print_BCBP    1  DEM3GZ               EWR
# 2 2021-09-20 00:40:48.207  Print_BCBP    1  4Q2B6B               EWR
# 3 2021-09-12 22:08:31.853  Print_BCBP    1  FKWM7U               MCO
# 4 2021-09-10 08:57:27.193  Print_BCBP    1  VK9M5K               LAS
#
#   TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE COMPARTMENT_CODE  \
# 0             BUR           NK          1652  2021-09-28                Y
# 1             MYR           NK            54  2021-09-26                Y
# 2             RZE           LO            18  2021-09-19                Y
# 3             ORD           NK           912  2021-09-13                Y
# 4             BUR           NK          1652  2021-09-10                Y
#
#   SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  AIRLINE_NUMERIC_CODE  \
# 0        026D              61                1                 487.0
# 1           0             166                1                 487.0
# 2        015B              87                3                  80.0
# 3        035C              92                1                 487.0
# 4        022E              57                1                 487.0
#
#   DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 0       0TT11XK1K8                 3.0
# 1                0                 0.0
# 2       7643411085                 0.0
# 3       0TT11SNKYY                 3.0
# 4                0                 0.0
#
#    INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 0                                       0.0                    NaN
# 1                                       0.0                    NaN
# 2                                       NaN                    LO
# 3                                       0.0                    NaN
# 4                                       0.0                    NaN
#
#    FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 0                        NaN                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2                        NaN                    NaN             NaN
# 3                        NaN                    NaN             NaN
# 4                        NaN                    NaN             NaN
#
#   FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2
# 0                    NaN         NaN 2021-09-28 09:47:22.980
# 1                    NaN         NaN 2021-09-26 20:04:50.247
# 2                    NaN         NaN 2021-09-20 02:23:55.090
# 3                    NaN         NaN 2021-09-12 22:09:13.287
# 4                    NaN         NaN 2021-09-10 08:57:52.870

# %%
brd.FLIGHT_NUMBER.isna().sum()
# Out:
# 4930

# %%
#filter out 4,930 rows with no flight info
brd1 = brd[brd.FLIGHT_NUMBER.notna()]
brd1.shape
# Out:
# (340062, 33)

# %%
#drop useless columns
brd1 = brd1.drop(['RTS_DATA', 'RTS_ENQUEUED','PROK','TS','LEG'],axis=1)

# %% [markdown]
# ## Compare total check-in vs boarding numbers

# %%
#how many of these are check-ins vs boardings?
brd1.LOCATION_POINT.value_counts()
# Out:
# 1    226210
# 7    113852
# Name: LOCATION_POINT, dtype: int64

# %%
#weird that there are more check-ins than boardings. Expected the opposite (because mobile checkins are excluded).
# Who is checking in that isn't boarding?
brdbrd = brd1[brd1['LOCATION_POINT'] == 7]
chn = brd1[brd1['LOCATION_POINT'] == 1]
chnbrd = brd1[(brd1['LOCATION_POINT'] == 1) & (~brd1['HASH_DATA'].isin(brdbrd['HASH_DATA']))]
brdnch = brd1[(brd1['LOCATION_POINT'] == 7) & (~brd1['HASH_DATA'].isin(chn['HASH_DATA']))]
brch_matched = brd1[(brd1['HASH_DATA'].isin(chn['HASH_DATA'])) & (brd1['HASH_DATA'].isin(brdbrd['HASH_DATA']))]

print(f'Checkin AND boarded (includes both records): {brch_matched.shape[0]}')
print(f'Checkin but no board: {chnbrd.shape[0]}')
print(f'Board but no checkin: {brdnch.shape[0]}')
# Out:
# Checkin AND boarded (includes both records): 114821
# Checkin but no board: 162525
# Board but no checkin: 62716

# %%
#let's repeat this based on PNR record number instead of HASH_DATA
chnbrd_pn = brd1[(brd1['LOCATION_POINT'] == 1) & (~brd1['PNR'].isin(brdbrd['PNR']))]
brdnch_pn = brd1[(brd1['LOCATION_POINT'] == 7) & (~brd1['PNR'].isin(chn['PNR']))]
brch_matched_pn = brd1[(brd1['PNR'].isin(chn['PNR'])) & (brd1['PNR'].isin(brdbrd['PNR']))]

print(f'Checkin AND boarded (includes both records): {brch_matched_pn.shape[0]}')
print(f'Checkin but no board: {chnbrd_pn.shape[0]}')
print(f'Board but no checkin: {brdnch_pn.shape[0]}')
# Out:
# Checkin AND boarded (includes both records): 153121
# Checkin but no board: 130691
# Board but no checkin: 56250

# %%
#I'm not sure why the PNR number does a better job than the HASH_DATA, but there are still lots of checkins without corresponding boardings

# %%
brd1.head()
# Out:
#                                      ID  \
# 0  9B25B853-96B0-477B-A57D-00000FD957E0
# 1  7EB30923-789D-4154-98C6-00001F18CD27
# 2  1826AF57-3129-4355-9DEF-000058C854B7
# 3  EF168078-B7C3-4BCF-A8C2-0000A1142BA4
# 4  28D1C99A-40D5-4A40-9381-0000A7373B6F
#
#                                   HASH_DATA       EVENT_LOGTIME  \
# 0  BFE97412EC0C9F94B91CD25F77E5004DE15F0248 2021-09-28 05:45:45
# 1  61D727C12F09B1FD803E5614E3EDD81B9D6CA217 2021-09-26 16:04:55
# 2  A7E458694C3A1E2A0AB99D535538F8F50B621479 2021-09-19 20:41:14
# 3  96D0CEC3B0DEA035F491F369E24380D2975C54A8 2021-09-12 18:08:49
# 4  0F7F8061D3461E0D144933171EE09C6720ECDE8B 2021-09-10 04:56:43
#
#    LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE     PNR  \
# 0               1  EWRBAKB018 2021-09-28 09:46:50.107  Print_BCBP  FM6RPE
# 1               1  EWRBAKB001 2021-09-26 20:04:50.247  Print_BCBP  DEM3GZ
# 2               1  EWRBCKB087 2021-09-20 00:40:48.207  Print_BCBP  4Q2B6B
# 3               1  EWRBCKB097 2021-09-12 22:08:31.853  Print_BCBP  FKWM7U
# 4               1  EWRBAKB005 2021-09-10 08:57:27.193  Print_BCBP  VK9M5K
#
#   FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE  \
# 0               LAS             BUR           NK          1652  2021-09-28
# 1               EWR             MYR           NK            54  2021-09-26
# 2               EWR             RZE           LO            18  2021-09-19
# 3               MCO             ORD           NK           912  2021-09-13
# 4               LAS             BUR           NK          1652  2021-09-10
#
#   COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  \
# 0                Y        026D              61                1
# 1                Y           0             166                1
# 2                Y        015B              87                3
# 3                Y        035C              92                1
# 4                Y        022E              57                1
#
#    AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 0                 487.0       0TT11XK1K8                 3.0
# 1                 487.0                0                 0.0
# 2                  80.0       7643411085                 0.0
# 3                 487.0       0TT11SNKYY                 3.0
# 4                 487.0                0                 0.0
#
#    INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 0                                       0.0                    NaN
# 1                                       0.0                    NaN
# 2                                       NaN                    LO
# 3                                       0.0                    NaN
# 4                                       0.0                    NaN
#
#    FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 0                        NaN                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2                        NaN                    NaN             NaN
# 3                        NaN                    NaN             NaN
# 4                        NaN                    NaN             NaN
#
#   FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2
# 0                    NaN         NaN 2021-09-28 09:47:22.980
# 1                    NaN         NaN 2021-09-26 20:04:50.247
# 2                    NaN         NaN 2021-09-20 02:23:55.090
# 3                    NaN         NaN 2021-09-12 22:09:13.287
# 4                    NaN         NaN 2021-09-10 08:57:52.870

# %%
#check columns to see if a certain variable contains a disproportionate number of the missing records
for c in ['WORKSTATION','EVENT_TYPE','FROM_AIRPORT_CODE','TO_AIRPORT_CODE','CARRIER_CODE','FLIGHT_NUMBER','COMPARTMENT_CODE']:
    comp = pd.concat([(brd1[c].value_counts(dropna=False) / brd1.shape[0]),(chnbrd_pn[c].value_counts(dropna=False) / chnbrd_pn.shape[0])], axis =1)
    comp.columns = ['all_records','chnbrd']
    comp['dif'] = comp.all_records - comp.chnbrd
    for x in comp.index:
        if comp.loc[x,'dif'] < -.1:
            print(f'{c} == {x} explains a disproportionate number of the missing boardings')
        if comp.loc[x,'dif'] > .1:
            print(f'{c} != {x} explains a disproportionate number of the missing boardings')
# Out:
# EVENT_TYPE == Print_BCBP explains a disproportionate number of the missing boardings
# EVENT_TYPE != Scan_BCBP explains a disproportionate number of the missing boardings
# CARRIER_CODE == NK explains a disproportionate number of the missing boardings
# COMPARTMENT_CODE == Y explains a disproportionate number of the missing boardings

# %%
#Spirit Airlines has the majority of missing boardings (101k or 77%), while JetBlue has none. What do they do differently?
comp = pd.concat([(brd1['CARRIER_CODE'].value_counts(dropna=False) / brd1.shape[0]),(chnbrd_pn['CARRIER_CODE'].value_counts(dropna=False) / chnbrd_pn.shape[0])], axis =1)
comp.columns = ['all_records','chnbrd']
comp['dif'] = comp.all_records - comp.chnbrd
comp.sort_values(by='dif',inplace=True)
comp
# Out:
#      all_records    chnbrd       dif
# NK      0.430918  0.774958 -0.344039
# PD      0.010298  0.024355 -0.014057
# EK      0.010748  0.021157 -0.010409
# ET      0.007437  0.016880 -0.009443
# BF      0.007604  0.016971 -0.009367
# F9      0.093842  0.102960 -0.009119
# B0      0.005834  0.011064 -0.005230
# KP      0.000632  0.001592 -0.000959
# OA      0.000126  0.000253 -0.000126
# FZ      0.000056  0.000138 -0.000082
# DL      0.000047  0.000122 -0.000075
# UA      0.000050  0.000077 -0.000027
# 250     0.000012  0.000031 -0.000019
# WN      0.000021  0.000031 -0.000010
# AS      0.000006  0.000015 -0.000009
# XK      0.000003  0.000008 -0.000005
# GF      0.000003  0.000008 -0.000005
# EY      0.000006  0.000008 -0.000002
# EW      0.000056  0.000015  0.000041
# ZB      0.000050  0.000008  0.000042
# OU      0.000276  0.000145  0.000131
# XQ      0.000206  0.000023  0.000183
# WK      0.000288  0.000069  0.000219
# PS      0.000300  0.000008  0.000292
# EN      0.000850  0.000138  0.000712
# FI      0.011627  0.000038  0.011589
# G4      0.016641  0.002984  0.013657
# LO      0.016124  0.001660  0.014463
# LX      0.018282  0.002418  0.015864
# SK      0.017129  0.000872  0.016257
# LY      0.024372  0.001752  0.022620
# OS      0.025316  0.000773  0.024543
# TK      0.039149  0.005218  0.033930
# AI      0.037231  0.000168  0.037063
# TP      0.052340  0.003229  0.049111
# LH      0.071610  0.009855  0.061755
# B6      0.093309       NaN       NaN
# SY      0.006946       NaN       NaN
# SN      0.000038       NaN       NaN
# AC      0.000035       NaN       NaN
# A3      0.000032       NaN       NaN
# KM      0.000029       NaN       NaN
# KC      0.000026       NaN       NaN
# NH      0.000012       NaN       NaN
# RFL     0.000012       NaN       NaN
# BT      0.000012       NaN       NaN
# WY      0.000012       NaN       NaN
# 4Y      0.000009       NaN       NaN
# 9I      0.000009       NaN       NaN
# BA      0.000006       NaN       NaN
# KQ      0.000006       NaN       NaN
# RJ      0.000006       NaN       NaN
# JU      0.000003       NaN       NaN
# 9K      0.000003       NaN       NaN
# AF      0.000003       NaN       NaN

# %%
#this seems reasonable. At check-in, most people are printing boarding passes with a few scanning, and at boarding, most records are scans with a few prints
brd1[['LOCATION_POINT','EVENT_TYPE','HASH_DATA']].groupby(by=['LOCATION_POINT','EVENT_TYPE']).count()
# Out:
#                            HASH_DATA
# LOCATION_POINT EVENT_TYPE
# 1              Print_BCBP     217973
#                Scan_BCBP        8237
# 7              Print_BCBP      11949
#                Scan_BCBP      101903

# %% [markdown]
# ## Explore the HASH_DATA field. What exactly does it correspond to?

# %%
#It is not unique. I expected it to correspond to a boarding pass, i.e. that there would be a record at checkin and boarding (total 2), 
# but there are some HASH_DATA values that occur many more times than that. Are these individuals who flew several times in September 2021?
brd1.HASH_DATA.value_counts()
# Out:
# 3A39B750C42BCFB3B557C5ECAF0FD56D3145E326    44
# 3A498E582D3217AE2DE63BADE218D375AAB0FFAE    31
# 2B8350552062B351B378AE1D0C888B4177BDE1DB    20
# 4A5759F137332EBFABF21D906413CD98FC3CD345    20
# 2A93215AF72502CDDD7619A09AA68D9729533D3E    15
#                                             ..
# 74D07B55833683FE94F0B7E7C18D53265E19DDA0     1
# 871741DFDE65B7236C0496FC85BF324C4B4A5413     1
# A53E9D0DB868C416CD919913E494014916E3A70C     1
# F30EF1CF79A2226547A29822D7DFBBA76E1D0395     1
# 4E0E844CB6CA74A83C1BB6DF656BE9CFF230CD9A     1
# Name: HASH_DATA, Length: 203125, dtype: int64

# %%
#let's look at the most common HASH_DATA value
FF = brd1[brd1['HASH_DATA'] == '3A39B750C42BCFB3B557C5ECAF0FD56D3145E326']

# %%
#This is confusing because this person apparently checked in several times on September 11 with the same seat number, which doesn't make sense.
FF.sort_values(by = ['EVENT_LOGTIME'], ascending=True, inplace = True)
FF.head()
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                           ID  \
# 316762  30AC5D0A-8952-4126-870F-EB15123BD4F5
# 135974  2A79C015-01B1-4167-9BE2-64E4BBF72652
# 6811    549D95AC-8E0C-4281-90E6-0523EB57CD25
# 191379  8C9A0CD2-3A28-4790-A480-8E30FF99D8E0
# 166007  389A8AD7-BBEC-461A-A457-7B554A487FD2
#
#                                        HASH_DATA       EVENT_LOGTIME  \
# 316762  3A39B750C42BCFB3B557C5ECAF0FD56D3145E326 2021-09-11 12:52:58
# 135974  3A39B750C42BCFB3B557C5ECAF0FD56D3145E326 2021-09-11 12:52:58
# 6811    3A39B750C42BCFB3B557C5ECAF0FD56D3145E326 2021-09-11 12:58:40
# 191379  3A39B750C42BCFB3B557C5ECAF0FD56D3145E326 2021-09-11 12:58:54
# 166007  3A39B750C42BCFB3B557C5ECAF0FD56D3145E326 2021-09-11 12:59:17
#
#         LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE  \
# 316762               1  EWRBAKB014 2021-09-11 16:53:10.257  Print_BCBP
# 135974               1  EWRBAKB014 2021-09-11 16:53:41.953  Print_BCBP
# 6811                 1  EWRBAKB014 2021-09-11 16:58:11.327   Scan_BCBP
# 191379               1  EWRBAKB014 2021-09-11 16:58:46.207   Scan_BCBP
# 166007               1  EWRBAKB014 2021-09-11 16:58:56.587   Scan_BCBP
#
#            PNR FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 316762  BCNZVC               EWR             IAH           NK           703
# 135974  BCNZVC               EWR             IAH           NK           703
# 6811    BCNZVC               EWR             IAH           NK           703
# 191379  BCNZVC               EWR             IAH           NK           703
# 166007  BCNZVC               EWR             IAH           NK           703
#
#        FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 316762  2021-09-11                Y        026F              96
# 135974  2021-09-11                Y        026F              96
# 6811    2021-09-11                Y        026F              96
# 191379  2021-09-11                Y        026F              96
# 166007  2021-09-11                Y        026F              96
#
#        PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 316762                3                 487.0                0
# 135974                3                 487.0                0
# 6811                  3                 487.0                0
# 191379                3                 487.0                0
# 166007                3                 487.0                0
#
#         SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 316762                 0.0                                       0.0
# 135974                 0.0                                       0.0
# 6811                   0.0                                       0.0
# 191379                 0.0                                       0.0
# 166007                 0.0                                       0.0
#
#        MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 316762                    NaN                        NaN
# 135974                    NaN                        NaN
# 6811                      NaN                        NaN
# 191379                    NaN                        NaN
# 166007                    NaN                        NaN
#
#         FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 316762                    NaN             NaN                    NaN
# 135974                    NaN             NaN                    NaN
# 6811                      NaN             NaN                    NaN
# 191379                    NaN             NaN                    NaN
# 166007                    NaN             NaN                    NaN
#
#         FAST_TRACK      STAGING_TIMESTAMP2
# 316762         NaN 2021-09-11 17:15:08.860
# 135974         NaN 2021-09-11 17:15:08.860
# 6811           NaN 2021-09-11 17:15:08.860
# 191379         NaN 2021-09-11 17:15:08.860
# 166007         NaN 2021-09-11 17:15:08.860

# %%
#Also of the records associated with this HASH_DATA, all are for checkins, not boardings. This must be a fluke or a duplicate record.
FF.LOCATION_POINT.value_counts()
# Out:
# 1    44
# Name: LOCATION_POINT, dtype: int64

# %%
#Let's check a different HASH_DATA value
FF1 = brd1[brd1['HASH_DATA'] == '2A93215AF72502CDDD7619A09AA68D9729533D3E']
FF1.LOCATION_POINT.value_counts()
# Out:
# 1    15
# Name: LOCATION_POINT, dtype: int64

# %%
#this one also looks like duplicate check-ins.
FF1.sort_values(by = ['EVENT_LOGTIME'], ascending=True, inplace = True)
FF1.head()
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                           ID  \
# 20      F93BFA77-4A7E-44EC-B6BC-0004B6E35B9A
# 12543   06540A58-7E4A-4749-BA1D-095F4A92A509
# 310402  8FC4E38F-0D36-49DB-807F-E65310B8C1FC
# 136214  55487196-A7E8-4F18-B599-6513805C9303
# 149252  195539BC-1919-4221-9A35-6EF377B4D0FD
#
#                                        HASH_DATA       EVENT_LOGTIME  \
# 20      2A93215AF72502CDDD7619A09AA68D9729533D3E 2021-09-03 15:20:56
# 12543   2A93215AF72502CDDD7619A09AA68D9729533D3E 2021-09-03 15:20:56
# 310402  2A93215AF72502CDDD7619A09AA68D9729533D3E 2021-09-03 15:23:29
# 136214  2A93215AF72502CDDD7619A09AA68D9729533D3E 2021-09-03 15:24:12
# 149252  2A93215AF72502CDDD7619A09AA68D9729533D3E 2021-09-03 15:24:12
#
#         LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE  \
# 20                   1  EWRBAKB023 2021-09-03 19:21:04.863  Print_BCBP
# 12543                1  EWRBAKB023 2021-09-03 19:21:42.040  Print_BCBP
# 310402               1  EWRBAKB023 2021-09-03 19:23:40.410   Scan_BCBP
# 136214               1  EWRBAKB023 2021-09-03 19:24:45.050  Print_BCBP
# 149252               1  EWRBAKB023 2021-09-03 19:25:09.257  Print_BCBP
#
#            PNR FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 20      FYC3GI               EWR             BNA           NK          1174
# 12543   FYC3GI               EWR             BNA           NK          1174
# 310402  FYC3GI               EWR             BNA           NK          1174
# 136214  FYC3GI               EWR             BNA           NK          1174
# 149252  FYC3GI               EWR             BNA           NK          1174
#
#        FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 20      2021-09-03                Y        023B              96
# 12543   2021-09-03                Y        023B              96
# 310402  2021-09-03                Y        023B              96
# 136214  2021-09-03                Y        023B              96
# 149252  2021-09-03                Y        023B              96
#
#        PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 20                    1                 487.0                0
# 12543                 1                 487.0                0
# 310402                1                 487.0                0
# 136214                1                 487.0                0
# 149252                1                 487.0                0
#
#         SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 20                     0.0                                       0.0
# 12543                  0.0                                       0.0
# 310402                 0.0                                       0.0
# 136214                 0.0                                       0.0
# 149252                 0.0                                       0.0
#
#        MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 20                        NaN                        NaN
# 12543                     NaN                        NaN
# 310402                    NaN                        NaN
# 136214                    NaN                        NaN
# 149252                    NaN                        NaN
#
#         FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 20                        NaN             NaN                    NaN
# 12543                     NaN             NaN                    NaN
# 310402                    NaN             NaN                    NaN
# 136214                    NaN             NaN                    NaN
# 149252                    NaN             NaN                    NaN
#
#         FAST_TRACK      STAGING_TIMESTAMP2
# 20             NaN 2021-09-03 19:51:53.490
# 12543          NaN 2021-09-03 19:51:53.490
# 310402         NaN 2021-09-03 19:51:53.490
# 136214         NaN 2021-09-03 19:51:53.490
# 149252         NaN 2021-09-03 19:51:53.490

# %%
#how many duplicate records are there
brd1.duplicated(subset=['HASH_DATA','LOCATION_POINT','WORKSTATION','EVENT_TYPE','PNR','FROM_AIRPORT_CODE','TO_AIRPORT_CODE','CARRIER_CODE','FLIGHT_NUMBER','FLIGHT_DATE','SEAT_NUMBER','SEQUENCE_NUMBER']).sum()
# Out:
# 74376

# %%
#most of those duplicates came from Spirit. Let's drop all of these duplicates.
brd1.loc[brd1.duplicated(subset=['HASH_DATA','LOCATION_POINT','WORKSTATION','EVENT_TYPE','PNR','FROM_AIRPORT_CODE','TO_AIRPORT_CODE','CARRIER_CODE','FLIGHT_NUMBER','FLIGHT_DATE','SEAT_NUMBER','SEQUENCE_NUMBER']),'CARRIER_CODE'].value_counts()
# Out:
# NK     64203
# AI      1407
# F9      1331
# TK      1187
# B6      1055
# B0       959
# LH       947
# TP       612
# OS       397
# LY       392
# LX       319
# SK       266
# ET       264
# LO       236
# PD       184
# FI       142
# BF       141
# EK       126
# G4       112
# SY        31
# WK        10
# PS        10
# DL         7
# AC         6
# XQ         5
# OA         4
# OU         3
# RFL        3
# KC         3
# EN         3
# UA         2
# ZB         2
# KP         2
# FZ         1
# AS         1
# 9I         1
# SN         1
# KQ         1
# Name: CARRIER_CODE, dtype: int64

# %%
brd1.drop_duplicates(subset=['HASH_DATA','LOCATION_POINT','EVENT_TYPE','PNR','FROM_AIRPORT_CODE','TO_AIRPORT_CODE','CARRIER_CODE','FLIGHT_NUMBER','FLIGHT_DATE','SEAT_NUMBER','SEQUENCE_NUMBER'],inplace=True)

# %%
#now let's check again. This is much more reasonable, but still who are the repeat HASH_DATA values?
brd1.HASH_DATA.value_counts()
# Out:
# E8408B15A568471BC91CBCAEC16AAA59123E2A5A    4
# 478A74BF8406B97499B6BDC323C49F4BE3591AD6    4
# D3FAE494A635642B96DDBE7BC907F5C915136FD9    4
# C1803909F05E105F3EE3D4A86ECB635755CB4552    4
# 8A7B82B21521C26CECAD0340C5C31494F937B633    4
#                                            ..
# AD3B5779ECC5167E5ED378A7E07159FF57C387F2    1
# D027B06ED151A266AFA2A7FE610F20775BCF17DE    1
# 0227A81E2F118A1AE8D8099519CB67DD9643D89C    1
# 9C61C3F8ED5765E1C492516C2E8B90AE6412827F    1
# 4E0E844CB6CA74A83C1BB6DF656BE9CFF230CD9A    1
# Name: HASH_DATA, Length: 203125, dtype: int64

# %%
#let's pick another one to explore. Looks like this person scanned and printed their boarding pass at both check-in and boarding, but it is the 
# same seat number, so I don't think this represents multiple people
FF2 = brd1[brd1['HASH_DATA'] == 'E8408B15A568471BC91CBCAEC16AAA59123E2A5A']
FF2.sort_values(by = ['EVENT_LOGTIME'], ascending=True, inplace = True)
FF2.head()
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                           ID  \
# 277379  3A4DDBB7-1245-4304-86F9-CDF7CFF64591
# 116726  9ED2C21D-23AB-4754-8E4A-569164094086
# 5406    AFF016F5-4974-4454-9A25-0416015F1E9E
# 164787  09449B8D-2ECD-4C8B-998E-7A6EF1FD4367
#
#                                        HASH_DATA       EVENT_LOGTIME  \
# 277379  E8408B15A568471BC91CBCAEC16AAA59123E2A5A 2021-09-15 04:07:36
# 116726  E8408B15A568471BC91CBCAEC16AAA59123E2A5A 2021-09-15 04:11:18
# 5406    E8408B15A568471BC91CBCAEC16AAA59123E2A5A 2021-09-15 05:35:51
# 164787  E8408B15A568471BC91CBCAEC16AAA59123E2A5A 2021-09-15 05:37:25
#
#         LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE  \
# 277379               1  EWRBAKB024 2021-09-15 08:08:04.730   Scan_BCBP
# 116726               1  EWRBAKB024 2021-09-15 08:12:25.357  Print_BCBP
# 5406                 7  EWRBGTC66A 2021-09-15 09:36:55.100  Print_BCBP
# 164787               7  EWRBGTP66B 2021-09-15 09:38:12.327   Scan_BCBP
#
#            PNR FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 277379  UD4Z2C               EWR             MCO           NK          1250
# 116726  UD4Z2C               EWR             MCO           NK          1250
# 5406    UD4Z2C               EWR             MCO           NK          1250
# 164787  UD4Z2C               EWR             MCO           NK          1250
#
#        FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 277379  2021-09-15                Y        036D              96
# 116726  2021-09-15                Y        036D              96
# 5406    2021-09-15                Y        036D              96
# 164787  2021-09-15                Y        036D              96
#
#        PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 277379                1                 487.0        656159059
# 116726                1                 487.0        656159059
# 5406                  1                 487.0        656159059
# 164787                1                 487.0        656159059
#
#         SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 277379                 0.0                                       0.0
# 116726                 0.0                                       0.0
# 5406                   0.0                                       0.0
# 164787                 0.0                                       0.0
#
#        MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 277379                    NaN                        NaN
# 116726                    NaN                        NaN
# 5406                      NaN                        NaN
# 164787                    NaN                        NaN
#
#         FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 277379                    NaN             NaN                    NaN
# 116726                    NaN             NaN                    NaN
# 5406                      NaN             NaN                    NaN
# 164787                    NaN             NaN                    NaN
#
#         FAST_TRACK      STAGING_TIMESTAMP2
# 277379         NaN 2021-09-15 09:38:12.327
# 116726         NaN 2021-09-15 09:38:12.327
# 5406           NaN 2021-09-15 09:38:12.327
# 164787         NaN 2021-09-15 09:38:12.327

# %%
#same as the last scenario. I think this means that each HASH_DATA represents a single boarding pass.
FF3 = brd1[brd1['HASH_DATA'] == '8A7B82B21521C26CECAD0340C5C31494F937B633']
FF3.sort_values(by = ['EVENT_LOGTIME'], ascending=True, inplace = True)
FF3.head()
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                           ID  \
# 165350  C5977B6A-B719-4EA1-94F5-7ADA6BC6014C
# 9772    04623B3F-D64B-4FD2-817F-074A5459055D
# 152306  99DB74F9-9495-4B82-A74B-713B62ADEFBC
# 297108  1E8C6038-A7BD-4A94-899C-DC94D4E6131F
#
#                                        HASH_DATA       EVENT_LOGTIME  \
# 165350  8A7B82B21521C26CECAD0340C5C31494F937B633 2021-09-23 03:56:57
# 9772    8A7B82B21521C26CECAD0340C5C31494F937B633 2021-09-23 03:58:44
# 152306  8A7B82B21521C26CECAD0340C5C31494F937B633 2021-09-23 04:21:37
# 297108  8A7B82B21521C26CECAD0340C5C31494F937B633 2021-09-23 04:44:13
#
#         LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE  \
# 165350               1  EWRBAKB013 2021-09-23 07:57:19.020  Print_BCBP
# 9772                 1  EWRBAKB013 2021-09-23 07:59:28.470   Scan_BCBP
# 152306               7  EWRBGTC67A 2021-09-23 08:21:32.300  Print_BCBP
# 297108               7  EWRBGTP67B 2021-09-23 08:45:12.917   Scan_BCBP
#
#            PNR FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 165350  RC8LRV               EWR             FLL           NK           521
# 9772    RC8LRV               EWR             FLL           NK           521
# 152306  RC8LRV               EWR             FLL           NK           521
# 297108  RC8LRV               EWR             FLL           NK           521
#
#        FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 165350  2021-09-23                Y        032F              26
# 9772    2021-09-23                Y        032F              26
# 152306  2021-09-23                Y        032F              26
# 297108  2021-09-23                Y        032F              26
#
#        PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 165350                3                 487.0                0
# 9772                  3                 487.0                0
# 152306                3                 487.0                0
# 297108                3                 487.0                0
#
#         SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 165350                 0.0                                       0.0
# 9772                   0.0                                       0.0
# 152306                 0.0                                       0.0
# 297108                 0.0                                       0.0
#
#        MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 165350                    NaN                        NaN
# 9772                      NaN                        NaN
# 152306                    NaN                        NaN
# 297108                    NaN                        NaN
#
#         FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 165350                    NaN             NaN                    NaN
# 9772                      NaN             NaN                    NaN
# 152306                    NaN             NaN                    NaN
# 297108                    NaN             NaN                    NaN
#
#         FAST_TRACK      STAGING_TIMESTAMP2
# 165350         NaN 2021-09-23 08:45:12.917
# 9772           NaN 2021-09-23 08:45:12.917
# 152306         NaN 2021-09-23 08:45:12.917
# 297108         NaN 2021-09-23 08:45:12.917

# %% [markdown]
# ## If the HASH_DATA is for a single boarding pass, what exactly does the PNR represent?

# %%
brd1.PNR.value_counts()
# Out:
# ZZZZZZZ    889
# G9G1HM     134
# PEJZ3R     129
# PYLABJ      84
# THXUG3      79
#           ...
# GLGEGN       1
# ADQ55Z       1
# 9b483f3      1
# AFND6D       1
# X6GWPL       1
# Name: PNR, Length: 109557, dtype: int64

# %%
#The PNR appears to be the confirmation number, which could include multiple people. For example, this PNR appears to be a large group trip
#But again, note that these are all check-ins -- no boarding records! Still a mystery how we have check-in but no boarding scans.
pnr1 = brd1[brd1['PNR'] == 'G9G1HM']
pnr1.sort_values(by = ['EVENT_LOGTIME'], ascending=True, inplace = True)
pnr1.head()
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                           ID  \
# 74049   1069A0D9-396E-4050-8E2B-370249C3D0F0
# 89747   2A5DC3F1-4D83-4C9D-A0FA-42A262B7E486
# 238345  6FC6E1B3-03E3-41C8-B97B-B0E354AA9A05
# 202601  ABB16671-CE69-4F07-9F49-969C08E298F1
# 151741  96D4F488-7E62-4974-BC64-70CAE31A5489
#
#                                        HASH_DATA       EVENT_LOGTIME  \
# 74049   F0E89B59B6590C107B04F8275D8282BF9195AEE6 2021-09-25 18:17:51
# 89747   9D20CFF28C45871A780577B7FE42509A94DD7B3C 2021-09-25 18:28:49
# 238345  D6088A253F6A978C539A80211E37619FC9B49E24 2021-09-25 18:28:54
# 202601  DCAAECE170FF21D633DED618FA04BF219D007C0F 2021-09-25 18:28:58
# 151741  08268FEB388D2606AE98416DD1F7A43697D1A582 2021-09-25 18:29:03
#
#         LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE  \
# 74049                1  EWRBCKB122 2021-09-25 22:17:38.720  Print_BCBP
# 89747                1  EWRBCKB122 2021-09-25 22:29:00.020  Print_BCBP
# 238345               1  EWRBCKB122 2021-09-25 22:29:01.503  Print_BCBP
# 202601               1  EWRBCKB122 2021-09-25 22:29:02.880  Print_BCBP
# 151741               1  EWRBCKB122 2021-09-25 22:29:04.273  Print_BCBP
#
#            PNR FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 74049   G9G1HM               EWR             MCO           F9          1259
# 89747   G9G1HM               EWR             MCO           F9          1259
# 238345  G9G1HM               EWR             MCO           F9          1259
# 202601  G9G1HM               EWR             MCO           F9          1259
# 151741  G9G1HM               EWR             MCO           F9          1259
#
#        FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 74049   2021-09-25                Y        028D              12
# 89747   2021-09-25                Y        011A              13
# 238345  2021-09-25                Y        011B              14
# 202601  2021-09-25                Y        011C              15
# 151741  2021-09-25                Y        011D              16
#
#        PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 74049                 3                   0.0                0
# 89747                 3                   0.0                0
# 238345                3                   0.0                0
# 202601                3                   0.0                0
# 151741                3                   0.0                0
#
#         SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 74049                  0.0                                       0.0
# 89747                  0.0                                       0.0
# 238345                 0.0                                       0.0
# 202601                 0.0                                       0.0
# 151741                 0.0                                       0.0
#
#        MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 74049                     NaN                        NaN
# 89747                     NaN                        NaN
# 238345                    NaN                        NaN
# 202601                    NaN                        NaN
# 151741                    NaN                        NaN
#
#         FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 74049                     NaN             NaN                    NaN
# 89747                     NaN             NaN                    NaN
# 238345                    NaN             NaN                    NaN
# 202601                    NaN             NaN                    NaN
# 151741                    NaN             NaN                    NaN
#
#         FAST_TRACK      STAGING_TIMESTAMP2
# 74049          NaN 2021-09-25 22:17:38.720
# 89747          NaN 2021-09-25 22:29:00.020
# 238345         NaN 2021-09-25 22:29:01.503
# 202601         NaN 2021-09-25 22:29:02.880
# 151741         NaN 2021-09-25 22:29:04.273

# %% [markdown]
# ## I'm curious about the SEQUENCE_NUMBER - does it account for mobile/online check-ins?

# %%
brd1.SEQUENCE_NUMBER.value_counts()
# Out:
# 1        7546
# 3        2038
# 2        2010
# 5        1966
# 4        1961
#          ...
# 530         1
# 518         1
# 529         1
# 0051r       1
# 0113r       1
# Name: SEQUENCE_NUMBER, Length: 787, dtype: int64

# %%
#have to get rid of some records and recast the sequence to an int
brd1['dt_fl'] = brd1['EVENT_LOGTIME'].dt.strftime('%Y%m%d').astype(str) + brd1['FLIGHT_NUMBER'].astype(str) + brd1['CARRIER_CODE'].astype(str)
brd2 = brd1
brd2.SEQUENCE_NUMBER.dropna(inplace=True)
brd2 = brd2[brd2.SEQUENCE_NUMBER.astype(str).str.isnumeric()]
brd2.SEQUENCE_NUMBER = brd2.SEQUENCE_NUMBER.astype(int)
# Out:
# C:\Users\Gabriel\anaconda3\envs\ADS2\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
#what is the minimum SEQUENCE_NUMBER for each flight?
sqfl = brd2[['dt_fl','CARRIER_CODE','SEQUENCE_NUMBER']].groupby(by=['dt_fl','CARRIER_CODE'],as_index=False).min().sort_values('SEQUENCE_NUMBER')
sqfl
# Out:
#                 dt_fl CARRIER_CODE  SEQUENCE_NUMBER
# 6844    20210923694TK           TK                0
# 645     20210902881NK           NK                0
# 7429    20210925459TK           TK                0
# 3864    20210913708TK           TK                0
# 222     20210901659NK           NK                0
# ...               ...          ...              ...
# 3307  202109119999OLH           LH             9999
# 5550  202109189999OLH           LH             9999
# 4532  202109159999OLH           LH             9999
# 1030  202109039999OLH           LH             9999
# 9052  202109309999OLH           LH             9999
#
# [9053 rows x 3 columns]

# %%
#By airline, what is the average, min, and max starting SEQUENCE_NUMBER?
# This suggests that some airlines account for online/mobile check-ins in the SEQUENCE_NUMBER
sqfl[['CARRIER_CODE','SEQUENCE_NUMBER']].groupby(['CARRIER_CODE']).agg({'SEQUENCE_NUMBER':['mean','min','max']}).sort_values(('SEQUENCE_NUMBER','mean'))
# Out:
#              SEQUENCE_NUMBER
#                         mean  min   max
# CARRIER_CODE
# RFL                 0.000000    0     0
# DL                  1.000000    1     1
# 9K                  1.000000    1     1
# G4                  1.000000    1     1
# B0                  1.000000    1     1
# KQ                  1.000000    1     1
# BA                  2.000000    1     3
# 9I                  4.000000    1     7
# BT                  4.000000    3     5
# JU                  6.000000    6     6
# RJ                  6.000000    6     6
# PD                  6.189024    1    58
# SK                  7.370370    1    99
# TP                  7.614286    1   106
# FI                  8.285714    1   148
# AC                  8.333333    1    12
# ZB                 11.833333    1    26
# B6                 14.391608    1   175
# NH                 15.000000   15    15
# LO                 17.100529    1    68
# AI                 17.758514    1    88
# ET                 18.646465    1   118
# XQ                 21.869565    2    50
# KC                 22.333333   17    25
# KP                 23.763889    1   101
# SN                 24.000000    4    55
# EN                 24.061856    1    87
# SY                 24.333333    1   166
# EY                 27.000000    1    53
# A3                 29.500000   16    43
# F9                 31.736559    1   184
# WY                 32.000000   13    43
# WK                 32.030303    1   101
# OU                 33.352941    1    88
# OS                 35.331373    1   960
# EW                 35.615385    1   114
# TK                 36.533960    0   183
# NK                 37.796368    0   204
# 4Y                 44.500000    1    88
# GF                 45.000000   45    45
# LX                 46.045259    1   237
# PS                 53.368421   14   127
# OA                 54.400000    5   106
# FZ                 59.583333    1   145
# UA                 61.666667    1   126
# KM                 62.200000   36    79
# AF                 63.000000   63    63
# XK                 67.000000   67    67
# EK                 85.889571    1   331
# LH                142.183463    1  9999
# AS                150.000000  150   150
# LY               1311.260870    1  9999
# BF               4653.107143    1  9999

# %% [markdown]
# ## Prepare the SITA and flight schedule data to be merged for further analysis

# %%
#schedule and SITA data can be matched based on the combination of flight number, flight date, and airline.
#need the crosswalk between airline IATA and ICAO codes
al_map = pd.read_csv(r'C:\Users\Gabriel\OneDrive\CUSP\Spring 2022 Classes\Capstone\Data\Airlines Mapping.csv')
al_map.head()
# Out:
#       Marketing Airline Desc Marketing Airline IATA Code  \
# 0             ABC Aerolineas                          4O
# 1                 Aer Lingus                          EI
# 2     Aeroenlaces Nacionales                          VB
# 3  Aeroflot Russian Airlines                          SU
# 4      Aerolineas Argentinas                          AR
#
#   Marketing Airline ICAO Code Marketing Airline Country
# 0                         AIJ                    Mexico
# 1                         EIN                   Ireland
# 2                         VIV                    Mexico
# 3                         AFL                    Russia
# 4                         ARG                 Argentina

# %%
#filter schedule data for september 2021
fsched_0921 = fsched[(fsched['month'] == 9) & (fsched['year'] == 2021)]
fsched_0921.shape
# Out:
# (4976, 24)

# %%
fsched_0921 = fsched_0921.merge(al_map[['Marketing Airline IATA Code','Marketing Airline ICAO Code']],left_on='Operating Airline ICAO Code',right_on='Marketing Airline ICAO Code')
fsched_0921.rename({'Marketing Airline IATA Code':'OpAL_IATACode','Marketing Airline ICAO Code_y':'OpAL_ICAOCode'},axis =1, inplace=True)

# %%
#we only want departing flights from Newark
fsched_0921 = fsched_0921[fsched_0921['Flight Direction'] == 'Departure']

# %%
#filter out transfer passengers from boarding data
brd1 = brd1[brd1['FROM_AIRPORT_CODE'] == 'EWR']
brd1.shape
# Out:
# (298166, 28)

# %%
fsched_0921['Flight Number'] = fsched_0921['Flight Number'].astype(int)
fsched_0921['Flight Number'] = fsched_0921['Flight Number'].astype(str)

# %%
fsched_0921['dt_fl'] = fsched_0921['datt'].dt.strftime('%Y%m%d').astype(str) + fsched_0921['Flight Number'].astype(str) + fsched_0921['OpAL_IATACode']
brd1['dt_fl'] = brd1['EVENT_LOGTIME'].dt.strftime('%Y%m%d').astype(str) + brd1['FLIGHT_NUMBER'].astype(str) + brd1['CARRIER_CODE'].astype(str)

# %% [markdown]
# ## Check how many flights are missing from the checkin/boarding data

# %%
#I want to see how many scheduled flights are missing from the SITA data. Do an outer join to keep flight schedule data with missing passenger records
mrf = pd.merge(fsched_0921, brd1, how = 'outer',left_on = 'dt_fl', right_on = 'dt_fl', indicator = True)
mrf.head()
# Out:
#          Date Military Time Flight Direction PA Airport Code   Terminal Desc  \
# 0  2021-09-01      05:00:00        Departure             EWR  EWR-Terminal B
# 1  2021-09-01      05:00:00        Departure             EWR  EWR-Terminal B
# 2  2021-09-01      05:00:00        Departure             EWR  EWR-Terminal B
# 3  2021-09-01      05:00:00        Departure             EWR  EWR-Terminal B
# 4  2021-09-01      05:00:00        Departure             EWR  EWR-Terminal B
#
#   Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 0                 FLL                         USA               Domestic
# 1                 FLL                         USA               Domestic
# 2                 FLL                         USA               Domestic
# 3                 FLL                         USA               Domestic
# 4                 FLL                         USA               Domestic
#
#   State Desc Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 0    Florida        Spirit Airlines                           NKS
# 1    Florida        Spirit Airlines                           NKS
# 2    Florida        Spirit Airlines                           NKS
# 3    Florida        Spirit Airlines                           NKS
# 4    Florida        Spirit Airlines                           NKS
#
#   Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 0        Spirit Airlines                         NKS           521
# 1        Spirit Airlines                         NKS           521
# 2        Spirit Airlines                         NKS           521
# 3        Spirit Airlines                         NKS           521
# 4        Spirit Airlines                         NKS           521
#
#      General Aircraft Desc    Variant Aircraft Desc Variant Aircraft Code  \
# 0  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
# 1  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
# 2  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
# 3  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
# 4  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
#
#    Total Seats  Flight Distance  Total Flights                datt  month  \
# 0        228.0           1065.0            1.0 2021-09-01 05:00:00    9.0
# 1        228.0           1065.0            1.0 2021-09-01 05:00:00    9.0
# 2        228.0           1065.0            1.0 2021-09-01 05:00:00    9.0
# 3        228.0           1065.0            1.0 2021-09-01 05:00:00    9.0
# 4        228.0           1065.0            1.0 2021-09-01 05:00:00    9.0
#
#      year  dayperiod OpAL_IATACode OpAL_ICAOCode          dt_fl  \
# 0  2021.0  overnight            NK           NKS  20210901521NK
# 1  2021.0  overnight            NK           NKS  20210901521NK
# 2  2021.0  overnight            NK           NKS  20210901521NK
# 3  2021.0  overnight            NK           NKS  20210901521NK
# 4  2021.0  overnight            NK           NKS  20210901521NK
#
#                                      ID  \
# 0  B6E6AE49-EA54-4E82-A009-0050A803AB27
# 1  7790451F-7FFD-44FC-9A03-006CD8093891
# 2  FB00EF83-0C5A-4030-9EB7-00F1B89E9CDD
# 3  A33A0FED-8E85-4FA0-A402-01D6E3DFBBEA
# 4  3189473F-C9EE-40E6-AC4D-0211688E066E
#
#                                   HASH_DATA       EVENT_LOGTIME  \
# 0  C4D882109DFF8617AD377E61AC98D0608FF95A5E 2021-09-01 04:43:18
# 1  490907DB350F0F1866C2FE0594C8A100F5781CDC 2021-09-01 04:32:49
# 2  A6711E8215A95CBADEA95DE45721932BBA0D2C2F 2021-09-01 04:44:49
# 3  3DC22A5E26E68885B957FAF0F7067ACBA783528E 2021-09-01 04:36:42
# 4  3F6878C3472A7F939DC5B5220375C1F8F5508D7C 2021-09-01 03:43:42
#
#    LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE     PNR  \
# 0             7.0  EWRBGTP67B 2021-09-01 08:44:09.417  Print_BCBP  NELE8Z
# 1             7.0  EWRBGTC67A 2021-09-01 08:33:31.523  Print_BCBP  PC8Y2S
# 2             7.0  EWRBGTP67B 2021-09-01 08:45:48.867   Scan_BCBP  TFZ3HM
# 3             7.0  EWRBGTP67B 2021-09-01 08:36:49.297   Scan_BCBP  CDWZ3Z
# 4             1.0  EWRBAKB003 2021-09-01 07:44:41.990  Print_BCBP  GYZUFY
#
#   FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE  \
# 0               EWR             FLL           NK           521  2021-09-01
# 1               EWR             FLL           NK           521  2021-09-01
# 2               EWR             FLL           NK           521  2021-09-01
# 3               EWR             FLL           NK           521  2021-09-01
# 4               EWR             FLL           NK           521  2021-09-01
#
#   COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  \
# 0                Y        021D             196                3
# 1                Y        025A              31                1
# 2                Y        022B             140                3
# 3                Y        016E              92                1
# 4                Y        019D             134                1
#
#    AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 0                 487.0       00A3931885                 0.0
# 1                 487.0                0                 0.0
# 2                 487.0        661802249                 0.0
# 3                 487.0        558962205                 0.0
# 4                 487.0                0                 0.0
#
#    INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 0                                       0.0                    NaN
# 1                                       0.0                    NaN
# 2                                       0.0                    NaN
# 3                                       0.0                    NaN
# 4                                       0.0                    NaN
#
#    FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 0                        NaN                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2                        NaN                    NaN             NaN
# 3                        NaN                    NaN             NaN
# 4                        NaN                    NaN             NaN
#
#   FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2 _merge
# 0                    NaN         NaN 2021-09-01 08:44:09.417   both
# 1                    NaN         NaN 2021-09-01 08:44:42.690   both
# 2                    NaN         NaN 2021-09-01 08:45:48.867   both
# 3                    NaN         NaN 2021-09-01 08:36:49.297   both
# 4                    NaN         NaN 2021-09-01 08:44:44.577   both

# %%
#count the flights that had no matching passenger records by airline and compare with the total scheduled flights for that airline
comp = pd.concat([mrf.loc[mrf._merge == 'left_only','Operating Airline Desc'].value_counts(),fsched_0921['Operating Airline Desc'].value_counts()],axis=1)
comp.columns = ['missing','total_scheduled']
comp['perc'] = comp.missing / comp.total_scheduled
comp.fillna(0,inplace=True)
comp
# Out:
#                               missing  total_scheduled      perc
# Delta Air Lines                 308.0              314  0.980892
# Spirit Airlines                  16.0              549  0.029144
# Icelandair                        4.0               24  0.166667
# Porter Airlines                   4.0               77  0.051948
# Scandinavian Airlines System      3.0               51  0.058824
# TAP Portugal                      3.0               68  0.044118
# Lufthansa                         3.0               56  0.053571
# Frontier Airlines                 2.0              216  0.009259
# Austrian Airlines                 2.0               30  0.066667
# La Compagnie                      2.0               22  0.090909
# Swiss International Airlines      2.0               26  0.076923
# Emirates                          2.0               30  0.066667
# El Al Israel Airlines             1.0               19  0.052632
# Ethiopian Airlines                1.0               17  0.058824
# French Bee                        1.0               14  0.071429
# Allegiant Air                     0.0               43  0.000000
# Air India Limited                 0.0               17  0.000000
# LOT Polish Airlines               0.0               17  0.000000
# Sun Country Airlines              0.0               16  0.000000

# %%
#Clearly Delta does not use the SITA system. What's surprising is that there are a few Delta flights that do have checkin/boarding records
# but it's only a total of 6 records so it's probably just a fluke.
mrf.loc[mrf._merge == 'both','Operating Airline Desc'].value_counts()
# Out:
# Spirit Airlines                 125548
# Frontier Airlines                30679
# Lufthansa                        18230
# TAP Portugal                     17533
# Air India Limited                 8789
# El Al Israel Airlines             8281
# Austrian Airlines                 6623
# Scandinavian Airlines System      5817
# Allegiant Air                     5659
# Swiss International Airlines      4706
# LOT Polish Airlines               4108
# Icelandair                        3953
# Emirates                          3414
# Porter Airlines                   3060
# French Bee                        2545
# Ethiopian Airlines                2392
# Sun Country Airlines              2194
# La Compagnie                      1984
# Delta Air Lines                      9
# Name: Operating Airline Desc, dtype: int64

# %% [markdown]
# ## Use left merge to add the flight schedule information to the SITA data

# %%
#merge schedule data to passenger data
mr = pd.merge(brd1, fsched_0921, how = 'left',left_on = 'dt_fl', right_on = 'dt_fl', indicator = True)
mr.head()
# Out:
#                                      ID  \
# 0  7EB30923-789D-4154-98C6-00001F18CD27
# 1  1826AF57-3129-4355-9DEF-000058C854B7
# 2  8628EAB5-9076-4BEF-BFC0-0001128B47C7
# 3  2BE84DC1-7226-46EA-A7FD-00011653F787
# 4  10347D39-E697-42C1-8BC1-0001FD2DD47B
#
#                                   HASH_DATA       EVENT_LOGTIME  \
# 0  61D727C12F09B1FD803E5614E3EDD81B9D6CA217 2021-09-26 16:04:55
# 1  A7E458694C3A1E2A0AB99D535538F8F50B621479 2021-09-19 20:41:14
# 2  E33211F5EB2B7FEDF59CAF7F88D1FD2B28EBD39A 2021-09-17 06:34:41
# 3  E97173E9C1571FB60A741B406900BD066377A433 2021-09-17 16:50:59
# 4  EFF8BFF1133BA44B1ECE2BA8D801EC1EE211F6D8 2021-09-03 14:20:06
#
#    LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE     PNR  \
# 0               1  EWRBAKB001 2021-09-26 20:04:50.247  Print_BCBP  DEM3GZ
# 1               1  EWRBCKB087 2021-09-20 00:40:48.207  Print_BCBP  4Q2B6B
# 2               1  EWRBAKB002 2021-09-17 10:35:43.227  Print_BCBP  YI57MT
# 3               1  EWRBCKB024 2021-09-17 20:51:28.183  Print_BCBP  2ZYTFE
# 4               1  EWRBAKB018 2021-09-03 18:20:20.473  Print_BCBP  GB5F8F
#
#   FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE  \
# 0               EWR             MYR           NK            54  2021-09-26
# 1               EWR             RZE           LO            18  2021-09-19
# 2               EWR             FLL           NK          1312  2021-09-17
# 3               EWR             FRA           LH           403  2021-09-17
# 4               EWR             IAH           NK           703  2021-09-03
#
#   COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  \
# 0                Y           0             166                1
# 1                Y        015B              87                3
# 2                Y        019D              37                1
# 3                M        034H             231                3
# 4                Y        030A             126                3
#
#    AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 0                 487.0                0                 0.0
# 1                  80.0       7643411085                 0.0
# 2                 487.0                0                 0.0
# 3                  16.0       2365562683                 0.0
# 4                 487.0                0                 0.0
#
#    INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 0                                       0.0                    NaN
# 1                                       NaN                    LO
# 2                                       0.0                    NaN
# 3                                       NaN                    LH
# 4                                       0.0                    NaN
#
#    FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 0                        NaN                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2                        NaN                    NaN             NaN
# 3                        NaN                    NaN             NaN
# 4                        NaN                    NaN             NaN
#
#   FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2           dt_fl  \
# 0                    NaN         NaN 2021-09-26 20:04:50.247    2021092654NK
# 1                    NaN         NaN 2021-09-20 02:23:55.090    2021091918LO
# 2                    NaN         NaN 2021-09-17 10:35:43.227  202109171312NK
# 3                    NaN         NaN 2021-09-17 20:51:28.183   20210917403LH
# 4                    NaN         NaN 2021-09-03 18:20:55.640   20210903703NK
#
#          Date Military Time Flight Direction PA Airport Code   Terminal Desc  \
# 0  2021-09-26      18:08:00        Departure             EWR  EWR-Terminal B
# 1  2021-09-19      22:55:00        Departure             EWR  EWR-Terminal B
# 2  2021-09-17      08:00:00        Departure             EWR  EWR-Terminal B
# 3  2021-09-17      18:05:00        Departure             EWR  EWR-Terminal B
# 4  2021-09-03      15:22:00        Departure             EWR  EWR-Terminal B
#
#   Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 0                 MYR                         USA               Domestic
# 1                 RZE                      Poland          International
# 2                 FLL                         USA               Domestic
# 3                 FRA                     Germany          International
# 4                 IAH                         USA               Domestic
#
#        State Desc Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 0  South Carolina        Spirit Airlines                           NKS
# 1   International    LOT Polish Airlines                           LOT
# 2         Florida        Spirit Airlines                           NKS
# 3   International              Lufthansa                           DLH
# 4           Texas        Spirit Airlines                           NKS
#
#   Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 0        Spirit Airlines                         NKS            54
# 1    LOT Polish Airlines                         LOT            18
# 2        Spirit Airlines                         NKS          1312
# 3              Lufthansa                         DLH           403
# 4        Spirit Airlines                         NKS           703
#
#      General Aircraft Desc    Variant Aircraft Desc Variant Aircraft Code  \
# 0  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
# 1               Boeing 787             Boeing 787-8                   788
# 2  Airbus A318/319/320/321  Airbus A320 (Sharklets)                   32A
# 3               Boeing 747             Boeing 747-8                   74H
# 4  Airbus A318/319/320/321  Airbus A321 (Sharklets)                   32B
#
#    Total Seats  Flight Distance  Total Flights                datt  month  \
# 0        228.0            550.0            1.0 2021-09-26 18:08:00    9.0
# 1        252.0           4392.0            1.0 2021-09-19 22:55:00    9.0
# 2        182.0           1065.0            1.0 2021-09-17 08:00:00    9.0
# 3        364.0           3869.0            1.0 2021-09-17 18:05:00    9.0
# 4        228.0           1400.0            1.0 2021-09-03 15:22:00    9.0
#
#      year  dayperiod OpAL_IATACode OpAL_ICAOCode _merge
# 0  2021.0    evening            NK           NKS   both
# 1  2021.0    evening            LO           LOT   both
# 2  2021.0    morning            NK           NKS   both
# 3  2021.0    evening            LH           DLH   both
# 4  2021.0  afternoon            NK           NKS   both

# %%
mr.shape
# Out:
# (298166, 56)

# %% [markdown]
# ## Evaluate the merge and figure out why some passenger records can't find a matching scheduled flight

# %%
mr._merge.value_counts()
# Out:
# both          190905
# left_only      40735
# right_only         0
# Name: _merge, dtype: int64

# %%
#can't figure out why the merge had so many non-matches....
noflights = mr[mr['_merge'] == 'left_only']
noflights.head(3)
# Out:
#                                       ID  \
# 8   80154ED4-6274-407B-9015-00039B037F98
# 26  ECBBA0C8-2D7D-49AE-8821-00065AB00D67
# 34  3DBED392-24B3-4C2F-83EF-0009A2885824
#
#                                    HASH_DATA       EVENT_LOGTIME  \
# 8   651F3E6663119688885867532F8EA9192E582AAC 2021-09-08 19:15:42
# 26  F2EBF648527F5D18269A5C79D94411EC6931ECAC 2021-09-29 22:05:11
# 34  09641A7A1C5BEA2C849FF740BF5AC61081379B43 2021-09-01 08:54:47
#
#     LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE     PNR  \
# 8                7  EWRBGTP22B 2021-09-08 23:15:35.470   Scan_BCBP  RXEXQO
# 26               1  EWRBCKB071 2021-09-30 02:05:16.050  Print_BCBP  RKHPNY
# 34               7  EWRBGTP21B 2021-09-01 12:55:38.670   Scan_BCBP  AIIJDG
#
#    FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE  \
# 8                EWR             MCO           B6           227  2021-09-08
# 26               EWR             IST           TK            30  2021-09-29
# 34               EWR             PUJ           B6          1015  2021-09-01
#
#    COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  \
# 8                 L        006D              54                1
# 26                Y        011J              13                1
# 34                P        007A             105                1
#
#     AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 8                  279.0              NaN                 0.0
# 26                 235.0       7616948587                 0.0
# 34                 279.0              NaN                 0.0
#
#     INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 8                                        NaN                    B6
# 26                                       1.0                    TK
# 34                                       NaN                    B6
#
#     FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 8                         NaN                    NaN             NaN
# 26                        NaN                    NaN             NaN
# 34                        NaN                    NaN             NaN
#
#    FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2           dt_fl  \
# 8                     NaN         NaN 2021-09-08 23:15:35.470   20210908227B6
# 26                    20K         NaN 2021-09-30 03:11:51.727    2021092930TK
# 34                    NaN         NaN 2021-09-01 12:55:38.670  202109011015B6
#
#    Date Military Time Flight Direction PA Airport Code Terminal Desc  \
# 8   NaN           NaN              NaN             NaN           NaN
# 26  NaN           NaN              NaN             NaN           NaN
# 34  NaN           NaN              NaN             NaN           NaN
#
#    Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 8                  NaN                         NaN                    NaN
# 26                 NaN                         NaN                    NaN
# 34                 NaN                         NaN                    NaN
#
#    State Desc Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 8         NaN                    NaN                           NaN
# 26        NaN                    NaN                           NaN
# 34        NaN                    NaN                           NaN
#
#    Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 8                     NaN                         NaN           NaN
# 26                    NaN                         NaN           NaN
# 34                    NaN                         NaN           NaN
#
#    General Aircraft Desc Variant Aircraft Desc Variant Aircraft Code  \
# 8                    NaN                   NaN                   NaN
# 26                   NaN                   NaN                   NaN
# 34                   NaN                   NaN                   NaN
#
#     Total Seats  Flight Distance  Total Flights datt  month  year  \
# 8           NaN              NaN            NaN  NaT    NaN   NaN
# 26          NaN              NaN            NaN  NaT    NaN   NaN
# 34          NaN              NaN            NaN  NaT    NaN   NaN
#
#    OpAL_IATACode OpAL_ICAOCode     _merge
# 8            NaN           NaN  left_only
# 26           NaN           NaN  left_only
# 34           NaN           NaN  left_only

# %%
#check columns to see if a certain variable contains a disproportionate number of the missing records
for c in ['WORKSTATION','EVENT_TYPE','FROM_AIRPORT_CODE','TO_AIRPORT_CODE','CARRIER_CODE','FLIGHT_NUMBER','COMPARTMENT_CODE']:
    comp = pd.concat([mr[c].value_counts(dropna=False),noflights[c].value_counts(dropna=False)], axis =1)
    comp.columns = ['all_records','noflights']
    comp['all_records_per'] = comp.all_records / mr.shape[0]
    comp['noflights_per'] = comp.noflights / noflights.shape[0]
    comp['dif'] = comp.all_records - comp.noflights
    comp['dif_per'] = comp.all_records_per - comp.noflights_per
    for x in comp.index:
        if comp.loc[x,'dif_per'] < -.1:
            print(f'{c} == {x} explains a disproportionate number of the missing flights.')
        if comp.loc[x,'dif_per'] > .1:
            print(f'{c} != {x} explains a disproportionate number of the missing flights.')
# Out:
# WORKSTATION == EWRBGTP21B explains a disproportionate number of the missing flights.
# WORKSTATION == EWRBGTP22B explains a disproportionate number of the missing flights.
# EVENT_TYPE != Print_BCBP explains a disproportionate number of the missing flights.
# EVENT_TYPE == Scan_BCBP explains a disproportionate number of the missing flights.
# TO_AIRPORT_CODE == IST explains a disproportionate number of the missing flights.
# CARRIER_CODE != NK explains a disproportionate number of the missing flights.
# CARRIER_CODE == B6 explains a disproportionate number of the missing flights.
# CARRIER_CODE == TK explains a disproportionate number of the missing flights.
# FLIGHT_NUMBER == 30 explains a disproportionate number of the missing flights.
# COMPARTMENT_CODE != Y explains a disproportionate number of the missing flights.
# COMPARTMENT_CODE == L explains a disproportionate number of the missing flights.

# %%
#Let's look more closely at the carrier
#Looks like NONE of the Jetblue or Turkish Airlines flights matched. Will need to look more closely at those. This accounts for almost all of the
# unmatched flights
#All the other mismatches are small enough that they could be due to 1-2 flights being rescheduled (i.e. not on the original flight schedule)
comp = pd.concat([mr['CARRIER_CODE'].value_counts(dropna=False),noflights['CARRIER_CODE'].value_counts(dropna=False)], axis =1)
comp.columns = ['all_records','noflights']
comp['all_records_per'] = comp.all_records / mr.shape[0]
comp['noflights_per'] = comp.noflights / noflights.shape[0]
comp.fillna(0,inplace=True)
comp['dif'] = comp.all_records - comp.noflights
comp['dif_per'] = comp.all_records_per - comp.noflights_per
for x in comp.index:
    if comp.loc[x,'dif_per'] < -.1:
        print(f'CARRIER_CODE == {x} explains a disproportionate number of the missing flights.')
    if comp.loc[x,'dif_per'] > .1:
        print(f'CARRIER_CODE != {x} explains a disproportionate number of the missing flights.')
comp.sort_values(by=['noflights_per'],ascending=False,inplace=True)
comp
# Out:
# CARRIER_CODE != NK explains a disproportionate number of the missing flights.
# CARRIER_CODE == B6 explains a disproportionate number of the missing flights.
# CARRIER_CODE != F9 explains a disproportionate number of the missing flights.
# CARRIER_CODE == TK explains a disproportionate number of the missing flights.
#      all_records  noflights  all_records_per  noflights_per      dif   dif_per
# B6         30591    30591.0         0.132063       0.750976      0.0 -0.618913
# TK          9065     9065.0         0.039134       0.222536      0.0 -0.183402
# LO          4504      586.0         0.019444       0.014386   3918.0  0.005058
# TP         17079      257.0         0.073731       0.006309  16822.0  0.067422
# SY          2323      161.0         0.010028       0.003952   2162.0  0.006076
# LH         17451       23.0         0.075337       0.000565  17428.0  0.074772
# BF          2391       15.0         0.010322       0.000368   2376.0  0.009954
# NK         68891        7.0         0.297405       0.000172  68884.0  0.297234
# WN             7        7.0         0.000030       0.000172      0.0 -0.000142
# AC             6        6.0         0.000026       0.000147      0.0 -0.000121
# UA             5        5.0         0.000022       0.000123      0.0 -0.000101
# 250            4        4.0         0.000017       0.000098      0.0 -0.000081
# LY          7810        4.0         0.033716       0.000098   7806.0  0.033618
# DL             9        3.0         0.000039       0.000074      6.0 -0.000035
# ET          2097        1.0         0.009053       0.000025   2096.0  0.009028
# SK          5518        0.0         0.023821       0.000000   5518.0  0.023821
# FI          3802        0.0         0.016413       0.000000   3802.0  0.016413
# EK          3283        0.0         0.014173       0.000000   3283.0  0.014173
# PD          2902        0.0         0.012528       0.000000   2902.0  0.012528
# G4          5543        0.0         0.023929       0.000000   5543.0  0.023929
# OS          6273        0.0         0.027081       0.000000   6273.0  0.027081
# B0          1024        0.0         0.004421       0.000000   1024.0  0.004421
# AI          7845        0.0         0.033867       0.000000   7845.0  0.033867
# F9         28765        0.0         0.124180       0.000000  28765.0  0.124180
# LX          4452        0.0         0.019219       0.000000   4452.0  0.019219

# %%
#Why didn't we get any matches for Turkish or Jetblue flights in the flight schedule?
#Looks like there aren't any Jetblue or Turkish flights in the flight schedule!
fsched_0921['Operating Airline Desc'].value_counts(dropna=False)
# Out:
# Spirit Airlines                 549
# Delta Air Lines                 314
# Frontier Airlines               216
# Porter Airlines                  77
# TAP Portugal                     68
# Lufthansa                        56
# Scandinavian Airlines System     51
# Allegiant Air                    43
# Austrian Airlines                30
# Emirates                         30
# Swiss International Airlines     26
# Icelandair                       24
# La Compagnie                     22
# El Al Israel Airlines            19
# Air India Limited                17
# Ethiopian Airlines               17
# LOT Polish Airlines              17
# Sun Country Airlines             16
# French Bee                       14
# Name: Operating Airline Desc, dtype: int64

# %%
#ditto for Marketing Airlines - no jetblue or turkish
fsched_0921['Marketing Airline Desc'].value_counts(dropna=False)
# Out:
# Spirit Airlines                 549
# Delta Air Lines                 314
# Frontier Airlines               216
# Porter Airlines                  77
# TAP Portugal                     68
# Lufthansa                        56
# Scandinavian Airlines System     51
# Allegiant Air                    43
# Austrian Airlines                30
# Emirates                         30
# Swiss International Airlines     26
# Icelandair                       24
# La Compagnie                     22
# El Al Israel Airlines            19
# Air India Limited                17
# Ethiopian Airlines               17
# LOT Polish Airlines              17
# Sun Country Airlines             16
# French Bee                       14
# Name: Marketing Airline Desc, dtype: int64

# %%
#let's look at the larger flight schedule data (outside of Sept 2021 and including arrivals)
#JetBlue does have flights here, but nothing from Turkish Airways. Why is Turkish missing, and why didn't JetBlue flights show up in the merge?
fsched['Operating Airline Desc'].value_counts()
# Out:
# United Airlines                              13526
# Spirit Airlines                               9803
# Delta Air Lines                               7832
# Frontier Airlines                             4686
# JetBlue Airways                               4091
# Endeavor Airlines                             2846
# Porter Airlines                               1476
# SkyWest                                       1260
# TAP Portugal                                  1151
# Lufthansa                                     1062
# Scandinavian Airlines System                   960
# Republic Airways                               824
# La Compagnie                                   612
# Allegiant Air                                  570
# Air India Limited                              536
# Swiss International Airlines                   522
# El Al Israel Airlines                          510
# Austrian Airlines                              470
# Emirates                                       428
# Ethiopian Airlines                             378
# Icelandair                                     301
# Sun Country Airlines                           282
# LOT Polish Airlines                            224
# French Bee                                     216
# British Airways                                186
# Aer Lingus                                      78
# Taca International Airlines                     20
# Avianca - Aerovias Nacionales de Colombia       16
# Name: Operating Airline Desc, dtype: int64

# %%
#Jetblue didn't have any scheduled departures in September 2021! Only arrivals. Why???
fsched.loc[(fsched['month'] == 9) & (fsched['year'] == 2021) & (fsched['Operating Airline Desc'] == 'JetBlue Airways'),'Flight Direction'].value_counts()
# Out:
# Arrival    391
# Name: Flight Direction, dtype: int64

# %%
fsched.loc[fsched['Operating Airline Desc'] == 'JetBlue Airways','Flight Direction'].value_counts()
# Out:
# Arrival      3366
# Departure     725
# Name: Flight Direction, dtype: int64

# %% [markdown]
# ## Ignoring all of the issues identified above, let's continue to compare boardings vs. schedule flights

# %%
#let's just look at boardings for passengers where we were able to match the flight schedule data
mrbr = mr[mr['LOCATION_POINT'] == 7]
mrbr = mrbr.dropna(subset=['datt'])
mrbr.shape
# Out:
# (72165, 55)

# %%
mrbr.head(3)
# Out:
#                                       ID  \
# 12  42729F38-1783-4ED3-A897-0004356DF141
# 19  D69FA86A-F826-43F4-A520-00055FF6FC83
# 28  BCF16F21-A8DC-4A8E-9DED-0006F7542B81
#
#                                    HASH_DATA       EVENT_LOGTIME  \
# 12  31E70F9948CCB2BBB1AF1DD49B17F3A9EA8D9B5B 2021-09-14 16:50:36
# 19  9D14CB81E56C20C8E9AC41D917D78F5F4BEB1D8F 2021-09-04 18:01:18
# 28  D2E038FA81B4A6F4E25EF5F6E45093AE69D4BD60 2021-09-20 22:26:08
#
#     LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP EVENT_TYPE     PNR  \
# 12               7  EWRBGTP60B 2021-09-14 20:51:20.180  Scan_BCBP  WZLOTF
# 19               7  EWRBGTS62B 2021-09-04 22:01:03.713  Scan_BCBP  P9KLE8
# 28               7  EWRBGTS62B 2021-09-21 02:26:29.963  Scan_BCBP  2U9U8H
#
#    FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE  \
# 12               EWR             VIE           OS            90  2021-09-14
# 19               EWR             FRA           LH           403  2021-09-04
# 28               EWR             WAW           LO            16  2021-09-20
#
#    COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  \
# 12                E        010A              40                3
# 19                M        032D             128                3
# 28                Y        027G              92                3
#
#     AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 12                 257.0       2151042891                 3.0
# 19                 220.0       2464283998                 0.0
# 28                  80.0       7649692800                 0.0
#
#     INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 12                                       NaN                    OS
# 19                                       NaN                    LH
# 28                                       NaN                    LO
#
#     FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 12                        NaN                    NaN             NaN
# 19                        NaN                    NaN             NaN
# 28                        NaN                    NaN             NaN
#
#    FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2          dt_fl  \
# 12                    NaN         NaN 2021-09-14 20:51:20.180   2021091490OS
# 19                    NaN         NaN 2021-09-04 22:01:03.713  20210904403LH
# 28                    NaN         NaN 2021-09-21 02:26:29.967   2021092016LO
#
#           Date Military Time Flight Direction PA Airport Code   Terminal Desc  \
# 12  2021-09-14      17:40:00        Departure             EWR  EWR-Terminal B
# 19  2021-09-04      18:05:00        Departure             EWR  EWR-Terminal B
# 28  2021-09-20      22:55:00        Departure             EWR  EWR-Terminal B
#
#    Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 12                 VIE                     Austria          International
# 19                 FRA                     Germany          International
# 28                 WAW                      Poland          International
#
#        State Desc Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 12  International      Austrian Airlines                           AUA
# 19  International              Lufthansa                           DLH
# 28  International    LOT Polish Airlines                           LOT
#
#    Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 12      Austrian Airlines                         AUA            90
# 19              Lufthansa                         DLH           403
# 28    LOT Polish Airlines                         LOT            16
#
#    General Aircraft Desc      Variant Aircraft Desc Variant Aircraft Code  \
# 12            Boeing 767  Boeing 767-300 (winglets)                   76W
# 19            Boeing 747               Boeing 747-8                   74H
# 28            Boeing 787               Boeing 787-8                   788
#
#     Total Seats  Flight Distance  Total Flights                datt  month  \
# 12        211.0           4253.0            1.0 2021-09-14 17:40:00    9.0
# 19        364.0           3869.0            1.0 2021-09-04 18:05:00    9.0
# 28        252.0           4278.0            1.0 2021-09-20 22:55:00    9.0
#
#       year OpAL_IATACode OpAL_ICAOCode _merge
# 12  2021.0            OS           AUA   both
# 19  2021.0            LH           DLH   both
# 28  2021.0            LO           LOT   both

# %%
mrbr['brdtime_fsched'] = (mrbr['EVENT_LOGTIME'] - mrbr['datt']).dt.total_seconds()/60

# %%
mrbr['brdtime_fsched'].hist(bins=48, range=[-120, 120])
# Out:
# <AxesSubplot:>

# %%
#let's look at the distribution of international vs. domestic boarding times
mrbr.loc[mrbr['International Domestic'] == 'International','brdtime_fsched'].hist(bins=48, range=[-120, 120], alpha = .5, color = 'blue')
mrbr.loc[mrbr['International Domestic'] == 'Domestic','brdtime_fsched'].hist(bins=48, range=[-120, 120], alpha=.5, color='red')
#mrbr['brdtime_fsched'].hist(bins=48, range=[-120, 120])
# Out:
# <AxesSubplot:>

# %%
#boarding time by airline
mrbr[['Operating Airline Desc','brdtime_fsched']].groupby(by=['Operating Airline Desc']).mean().sort_values(by='brdtime_fsched').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Operating Airline Desc'>

# %%
mr['International Domestic'].value_counts()
# Out:
# Domestic         102895
# International     88010
# Name: International Domestic, dtype: int64

# %%
mrbr['International Domestic'].value_counts()
# Out:
# International    41574
# Domestic         30591
# Name: International Domestic, dtype: int64

# %%
#passenger status? fast_track? frequent flyer?

# %%
#compare reported load factor against passenger boardings
lf = mrbr[['dt_fl','Total Seats','ID']].groupby(by='dt_fl').agg({'Total Seats':'mean','ID':'count'})
lf['load_factor'] = lf['ID'] / lf['Total Seats']
lf['load_factor'].hist()
# Out:
# <AxesSubplot:>

# %%
lf.sort_values('load_factor')
# Out:
#                 Total Seats   ID  load_factor
# dt_fl
# 20210907210EK         354.0    1     0.002825
# 20210916210EK         354.0    1     0.002825
# 20210918210EK         354.0    1     0.002825
# 20210904210EK         354.0    1     0.002825
# 20210929210EK         354.0    1     0.002825
# ...                     ...  ...          ...
# 2021092926LY          271.0  316     1.166052
# 20210902204TP         168.0  199     1.184524
# 2021092526LY          271.0  329     1.214022
# 20210914204TP         168.0  228     1.357143
# 202109021259F9        186.0  272     1.462366
#
# [639 rows x 3 columns]

# %%
np.sum(lf.ID)
# Out:
# 72165

# %%
np.sum(lf['Total Seats'])
# Out:
# 145232.0

# %% [markdown]
# ## Deep dive into 1 flight: LH403 from Newark to Frankfurt, departing Sept 17, 2021 at 6:05pm

# %%
lh403 = mr[mr['dt_fl'] == '20210917403LH']
lh403.head()
# Out:
#                                         ID  \
# 3     2BE84DC1-7226-46EA-A7FD-00011653F787
# 823   6725C4C6-515A-4F8E-A498-00B0B10628E4
# 1261  A970AD1F-D834-4011-8D6E-01128FE07CA1
# 1312  64395AF1-EE71-45E2-B2FB-011C1D413D39
# 1399  AEBBB3B8-5161-46F3-8583-01315CBD2C23
#
#                                      HASH_DATA       EVENT_LOGTIME  \
# 3     E97173E9C1571FB60A741B406900BD066377A433 2021-09-17 16:50:59
# 823   636EACDE9F45A089AA0E7A86CAB4FE025ECFF861 2021-09-17 17:56:46
# 1261  BC307FAEF9A5DC617998FE6F45DA5298A436BEB9 2021-09-17 16:12:44
# 1312  35A1BDCD5C1FD26B75B6A6D9253E643F620B2366 2021-09-17 17:45:12
# 1399  C3D7902A7C3B81C4192E9E4030B8D0EEF02E64E7 2021-09-17 16:16:47
#
#       LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE     PNR  \
# 3                  1  EWRBCKB024 2021-09-17 20:51:28.183  Print_BCBP  2ZYTFE
# 823                7  EWRBGTS62B 2021-09-17 21:56:55.120   Scan_BCBP  MSW5RI
# 1261               1  EWRBCKB021 2021-09-17 20:13:21.230  Print_BCBP  2QPMJC
# 1312               7  EWRBGTS62B 2021-09-17 21:45:35.273   Scan_BCBP  PGF4VR
# 1399               1  EWRBCKB030 2021-09-17 20:17:03.987  Print_BCBP  WIFU7B
#
#      FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER FLIGHT_DATE  \
# 3                  EWR             FRA           LH           403  2021-09-17
# 823                EWR             FRA           LH           403  2021-09-17
# 1261               EWR             FRA           LH           403  2021-09-17
# 1312               EWR             FRA           LH           403  2021-09-17
# 1399               EWR             FRA           LH           403  2021-09-17
#
#      COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER PASSENGER_STATUS  \
# 3                   M        034H             231                3
# 823                 M        018K             105                3
# 1261                M        040A              60                3
# 1312                M        045G              44                3
# 1399                M        019H              73                3
#
#       AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  SELECTEE_INDICATOR  \
# 3                     16.0       2365562683                 0.0
# 823                  220.0       2464903978                 0.0
# 1261                 220.0       7648707664                 3.0
# 1312                 220.0       2464953272                 0.0
# 1399                 220.0       2464502352                 0.0
#
#       INTERNATIONAL_DOCUMENTATION_VERIFICATION MARKETING_CARRIER_CODE  \
# 3                                          NaN                    LH
# 823                                        NaN                    LH
# 1261                                       NaN                    LH
# 1312                                       NaN                    LH
# 1399                                       NaN                    LH
#
#       FREQUENT_FLYER_DESIGNATOR  FREQUENT_FLYER_NUMBER  IDAD_INDICATOR  \
# 3                           NaN                    NaN             NaN
# 823                         NaN                    NaN             NaN
# 1261                        NaN                    NaN             NaN
# 1312                        NaN                    NaN             NaN
# 1399                        NaN                    NaN             NaN
#
#      FREE_BAGGAGE_ALLOWANCE  FAST_TRACK      STAGING_TIMESTAMP2  \
# 3                       NaN         NaN 2021-09-17 20:51:28.183
# 823                     NaN         NaN 2021-09-17 21:56:55.120
# 1261                    NaN         NaN 2021-09-17 21:37:28.380
# 1312                    NaN         NaN 2021-09-17 21:45:35.277
# 1399                    NaN         NaN 2021-09-17 21:50:01.697
#
#               dt_fl        Date Military Time Flight Direction  \
# 3     20210917403LH  2021-09-17      18:05:00        Departure
# 823   20210917403LH  2021-09-17      18:05:00        Departure
# 1261  20210917403LH  2021-09-17      18:05:00        Departure
# 1312  20210917403LH  2021-09-17      18:05:00        Departure
# 1399  20210917403LH  2021-09-17      18:05:00        Departure
#
#      PA Airport Code   Terminal Desc Non-PA Airport Code  \
# 3                EWR  EWR-Terminal B                 FRA
# 823              EWR  EWR-Terminal B                 FRA
# 1261             EWR  EWR-Terminal B                 FRA
# 1312             EWR  EWR-Terminal B                 FRA
# 1399             EWR  EWR-Terminal B                 FRA
#
#      Non-PA Airport Country Desc International Domestic     State Desc  \
# 3                        Germany          International  International
# 823                      Germany          International  International
# 1261                     Germany          International  International
# 1312                     Germany          International  International
# 1399                     Germany          International  International
#
#      Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 3                 Lufthansa                           DLH
# 823               Lufthansa                           DLH
# 1261              Lufthansa                           DLH
# 1312              Lufthansa                           DLH
# 1399              Lufthansa                           DLH
#
#      Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 3                 Lufthansa                         DLH           403
# 823               Lufthansa                         DLH           403
# 1261              Lufthansa                         DLH           403
# 1312              Lufthansa                         DLH           403
# 1399              Lufthansa                         DLH           403
#
#      General Aircraft Desc Variant Aircraft Desc Variant Aircraft Code  \
# 3               Boeing 747          Boeing 747-8                   74H
# 823             Boeing 747          Boeing 747-8                   74H
# 1261            Boeing 747          Boeing 747-8                   74H
# 1312            Boeing 747          Boeing 747-8                   74H
# 1399            Boeing 747          Boeing 747-8                   74H
#
#       Total Seats  Flight Distance  Total Flights                datt  month  \
# 3           364.0           3869.0            1.0 2021-09-17 18:05:00    9.0
# 823         364.0           3869.0            1.0 2021-09-17 18:05:00    9.0
# 1261        364.0           3869.0            1.0 2021-09-17 18:05:00    9.0
# 1312        364.0           3869.0            1.0 2021-09-17 18:05:00    9.0
# 1399        364.0           3869.0            1.0 2021-09-17 18:05:00    9.0
#
#         year OpAL_IATACode OpAL_ICAOCode _merge
# 3     2021.0            LH           DLH   both
# 823   2021.0            LH           DLH   both
# 1261  2021.0            LH           DLH   both
# 1312  2021.0            LH           DLH   both
# 1399  2021.0            LH           DLH   both

# %%
#491 SITA records
lh403.shape
# Out:
# (491, 55)

# %%
#260 passengers
lh403.HASH_DATA.nunique()
# Out:
# 260

# %%
#count of SITA records at check-in vs boarding. Most of these are probably the same passenger at both locations, but let's groupby to be sure
lh403.LOCATION_POINT.value_counts()
# Out:
# 7    275
# 1    216
# Name: LOCATION_POINT, dtype: int64

# %%
#looks like 237 people boarded and almost all of them printed their boarding pass at check-in
# I wonder if you aren't checking a bag, maybe you can check in online, but most people who fly internationally would be checking a bag.
lh403[['HASH_DATA','LOCATION_POINT','EVENT_TYPE']].groupby(by=['LOCATION_POINT','EVENT_TYPE']).agg(lambda x: x.nunique())
# Out:
#                            HASH_DATA
# LOCATION_POINT EVENT_TYPE
# 1              Print_BCBP        215
#                Scan_BCBP           1
# 7              Print_BCBP         38
#                Scan_BCBP         237

# %%
lh403.HASH_DATA.value_counts().sort_values(ascending=False)
# Out:
# F2231AF29F7A251584CB154F6973174DACEFA384    3
# D12689ECD92C8D71A7413FAE3ACCFD9E0267D1AD    2
# 79A6C68D7FD91158365999DF484976900AF9ED69    2
# BC307FAEF9A5DC617998FE6F45DA5298A436BEB9    2
# 35A1BDCD5C1FD26B75B6A6D9253E643F620B2366    2
#                                            ..
# A5C3C0DC7F7965C92E31ABD214ADC4276802A7D5    1
# E212180D2C8A0FD10C6EE14E837D6A1863A0C3FD    1
# BBEBE47C19F47FAB9A89B8D70CFB1D20295293BC    1
# D4EC05259E6493515DE6BA12F0FA991A67D7A021    1
# A536047B5B9FC8115181BDFB42E91048C414AACD    1
# Name: HASH_DATA, Length: 260, dtype: int64

# %%
#one passenger has 3 records. Looks like he had to have his boarding pass re-printed at boarding
lh403[lh403.HASH_DATA == 'F2231AF29F7A251584CB154F6973174DACEFA384']
# Out:
#                                           ID  \
# 45130   76187979-4211-495A-B3D2-28499F8B4BB6
# 51996   EB0ABD6E-A925-4FB1-B104-2EBD1B4DA6FB
# 228445  A866678D-99FD-4811-8CE3-FB8798F9374D
#
#                                        HASH_DATA       EVENT_LOGTIME  \
# 45130   F2231AF29F7A251584CB154F6973174DACEFA384 2021-09-17 18:00:06
# 51996   F2231AF29F7A251584CB154F6973174DACEFA384 2021-09-17 17:58:48
# 228445  F2231AF29F7A251584CB154F6973174DACEFA384 2021-09-17 14:54:27
#
#         LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE  \
# 45130                7  EWRBGTC62A 2021-09-17 22:00:22.220  Print_BCBP
# 51996                7  EWRBGTS62B 2021-09-17 21:59:10.607   Scan_BCBP
# 228445               1  EWRBCKB029 2021-09-17 18:54:33.420  Print_BCBP
#
#            PNR FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 45130   VJVBOS               EWR             FRA           LH           403
# 51996   VJVBOS               EWR             FRA           LH           403
# 228445  VJVBOS               EWR             FRA           LH           403
#
#        FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 45130   2021-09-17                E        024D             168
# 51996   2021-09-17                E        024D             168
# 228445  2021-09-17                E        024D             168
#
#        PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 45130                 3                 220.0       2465620801
# 51996                 3                 220.0       2465620801
# 228445                3                 220.0       2465620801
#
#         SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 45130                  0.0                                       NaN
# 51996                  0.0                                       NaN
# 228445                 0.0                                       NaN
#
#        MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 45130                     LH                         NaN
# 51996                     LH                         NaN
# 228445                    LH                         NaN
#
#         FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 45130                     NaN             NaN                    NaN
# 51996                     NaN             NaN                    NaN
# 228445                    NaN             NaN                    NaN
#
#         FAST_TRACK      STAGING_TIMESTAMP2          dt_fl        Date  \
# 45130          NaN 2021-09-17 22:00:23.260  20210917403LH  2021-09-17
# 51996          NaN 2021-09-17 22:00:23.260  20210917403LH  2021-09-17
# 228445         NaN 2021-09-17 22:00:23.260  20210917403LH  2021-09-17
#
#        Military Time Flight Direction PA Airport Code   Terminal Desc  \
# 45130       18:05:00        Departure             EWR  EWR-Terminal B
# 51996       18:05:00        Departure             EWR  EWR-Terminal B
# 228445      18:05:00        Departure             EWR  EWR-Terminal B
#
#        Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 45130                  FRA                     Germany          International
# 51996                  FRA                     Germany          International
# 228445                 FRA                     Germany          International
#
#            State Desc Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 45130   International              Lufthansa                           DLH
# 51996   International              Lufthansa                           DLH
# 228445  International              Lufthansa                           DLH
#
#        Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 45130               Lufthansa                         DLH           403
# 51996               Lufthansa                         DLH           403
# 228445              Lufthansa                         DLH           403
#
#        General Aircraft Desc Variant Aircraft Desc Variant Aircraft Code  \
# 45130             Boeing 747          Boeing 747-8                   74H
# 51996             Boeing 747          Boeing 747-8                   74H
# 228445            Boeing 747          Boeing 747-8                   74H
#
#         Total Seats  Flight Distance  Total Flights                datt  \
# 45130         364.0           3869.0            1.0 2021-09-17 18:05:00
# 51996         364.0           3869.0            1.0 2021-09-17 18:05:00
# 228445        364.0           3869.0            1.0 2021-09-17 18:05:00
#
#         month    year OpAL_IATACode OpAL_ICAOCode _merge
# 45130     9.0  2021.0            LH           DLH   both
# 51996     9.0  2021.0            LH           DLH   both
# 228445    9.0  2021.0            LH           DLH   both

# %%
#how many passengers only had 1 SITA record? (presumably boarding?)
s1 = lh403.HASH_DATA.value_counts()[lh403.HASH_DATA.value_counts() == 1]
s1.sum()
# Out:
# 30

# %%
# in fact, there are 16 people who checked in but didn't board. I bet these are people whose seats were changed at the gate
# They probably had new boarding passes printed.
one = lh403[lh403['HASH_DATA'].isin(s1.index)]
one.LOCATION_POINT.value_counts()
# Out:
# 1    16
# 7    14
# Name: LOCATION_POINT, dtype: int64

# %%
#It does look like some of these were under the same reservation code.
one.PNR.value_counts()
# Out:
# 3SB595     3
# KY3MWZ     3
# ZZZZZZZ    3
# 2ZYTFE     2
# 29BH47     2
# 2VLG8M     2
# 4L9O32     2
# US3YFT     1
# 2K4ZAO     1
# 4SEQXA     1
# 49HB3X     1
# VQWTGG     1
# S83SFQ     1
# LMKBYO     1
# 2BWLZ7     1
# J5HHJR     1
# 3DYNZD     1
# SBQ2PC     1
# MMW9FB     1
# SU9HTA     1
# Name: PNR, dtype: int64

# %%
lh403['brdtime_fsched'] = (lh403['EVENT_LOGTIME'] - lh403['datt']).dt.total_seconds()/60
# Out:
# C:\Users\Gabriel\AppData\Local\Temp/ipykernel_23256/4238585132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lh403['brdtime_fsched'] = (lh403['EVENT_LOGTIME'] - lh403['datt']).dt.total_seconds()/60

# %%
lh403.loc[lh403['LOCATION_POINT'] == 1,'brdtime_fsched'].hist(bins=48, range=[-120, 120])
# Out:
# <AxesSubplot:>

# %%
lh403.loc[lh403['LOCATION_POINT'] == 7,'brdtime_fsched'].hist(bins=48, range=[-120, 120])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Choose some other representative flights

# %%
#there are not nearly as many domestic flight destinations as I expected, e.g. no chicago, DC, California, etc.
fsched_0921[['dt_fl','State Desc','Operating Airline Desc','dayperiod']].groupby(['State Desc','dayperiod','Operating Airline Desc']).count()
# Out:
#                                                        dt_fl
# State Desc     dayperiod Operating Airline Desc
# Florida        afternoon Frontier Airlines                23
#                          Spirit Airlines                  64
#                evening   Frontier Airlines                62
#                          Spirit Airlines                  20
#                morning   Allegiant Air                     9
#                          Frontier Airlines                34
#                          Spirit Airlines                 101
#                overnight Spirit Airlines                  37
# Georgia        afternoon Delta Air Lines                  60
#                evening   Delta Air Lines                  19
#                          Spirit Airlines                  30
#                morning   Delta Air Lines                 130
#                          Frontier Airlines                30
#                          Spirit Airlines                  29
# International  afternoon Air India Limited                 2
#                          Austrian Airlines                30
#                          El Al Israel Airlines             4
#                          Porter Airlines                  26
#                          Scandinavian Airlines System     42
#                          TAP Portugal                     30
#                evening   El Al Israel Airlines            12
#                          Ethiopian Airlines               17
#                          French Bee                       14
#                          Icelandair                       24
#                          LOT Polish Airlines              17
#                          La Compagnie                     22
#                          Lufthansa                        56
#                          Porter Airlines                  14
#                          Scandinavian Airlines System      9
#                          Swiss International Airlines     26
#                          TAP Portugal                      8
#                morning   Air India Limited                15
#                          El Al Israel Airlines             1
#                          Frontier Airlines                30
#                          Porter Airlines                  37
#                overnight El Al Israel Airlines             2
#                          Emirates                         30
#                          TAP Portugal                     30
# Kentucky       morning   Allegiant Air                     8
# Louisiana      afternoon Spirit Airlines                   3
#                morning   Spirit Airlines                   8
# Massachusetts  afternoon Spirit Airlines                   4
#                evening   Spirit Airlines                  25
#                morning   Spirit Airlines                   2
# Michigan       morning   Allegiant Air                     9
#                          Delta Air Lines                  30
# Minnesota      afternoon Sun Country Airlines              1
#                evening   Delta Air Lines                  15
#                morning   Delta Air Lines                  30
#                          Sun Country Airlines             15
# Nevada         evening   Spirit Airlines                  23
#                morning   Spirit Airlines                  30
# North Carolina morning   Allegiant Air                     9
# Puerto Rico    morning   Spirit Airlines                  30
#                overnight Frontier Airlines                 7
# South Carolina afternoon Spirit Airlines                   8
#                evening   Spirit Airlines                  24
#                morning   Spirit Airlines                  32
# Tennessee      afternoon Spirit Airlines                   3
#                evening   Spirit Airlines                   9
#                morning   Allegiant Air                     8
#                          Spirit Airlines                  16
# Texas          afternoon Spirit Airlines                  29
#                evening   Spirit Airlines                   1
#                morning   Frontier Airlines                30
#                          Spirit Airlines                  21
# Utah           evening   Delta Air Lines                  18
#                morning   Delta Air Lines                  12

# %%
nk1357 = mr[(mr['dt_fl'] == '202109141357NK')]
nk1357.head()
# Out:
#                                          ID  \
# 11568  1A2510C9-9E8E-40BA-ACAF-0A06A34DE673
# 23309  04AE45AC-BFBC-4A68-A274-1484B3613416
# 26768  33C3749C-B0F1-4AA4-AD13-17A79CF921AA
# 31350  35CDB91E-823F-40EC-B8B2-1BB3CFE41A81
# 32269  BFFC109D-AB26-4C78-B0C2-1C8D0A912132
#
#                                       HASH_DATA       EVENT_LOGTIME  \
# 11568  9299B63E27599A830F399B98ACAF067F6193A14E 2021-09-14 20:14:16
# 23309  DB70DD7E3689D0319DDAFC4B845D6891DF66C958 2021-09-14 19:32:28
# 26768  205551E48B9C0BD28C0A5D9680BF579D9D25091A 2021-09-14 19:04:48
# 31350  DF933B0A588D9198F76DA761BBAD9F2204B1212A 2021-09-14 19:01:28
# 32269  51DC3F4DD592E21F03874B5AC4D4BC783B387C64 2021-09-14 13:31:19
#
#        LOCATION_POINT WORKSTATION       STAGING_TIMESTAMP  EVENT_TYPE     PNR  \
# 11568               1  EWRBAKB014 2021-09-15 00:15:10.580  Print_BCBP  AMS9RB
# 23309               1  EWRBCKB097 2021-09-14 23:32:43.737  Print_BCBP  WCU2NF
# 26768               1  EWRBCKB099 2021-09-14 23:05:47.340  Print_BCBP  BLTL5B
# 31350               1  EWRBAKB001 2021-09-14 23:02:12.633   Scan_BCBP  BLTL5B
# 32269               1  EWRBCKB097 2021-09-14 17:32:03.870  Print_BCBP  WD2TMF
#
#       FROM_AIRPORT_CODE TO_AIRPORT_CODE CARRIER_CODE FLIGHT_NUMBER  \
# 11568               EWR             BOS           NK          1357
# 23309               EWR             BOS           NK          1357
# 26768               EWR             BOS           NK          1357
# 31350               EWR             BOS           NK          1357
# 32269               EWR             BOS           NK          1357
#
#       FLIGHT_DATE COMPARTMENT_CODE SEAT_NUMBER SEQUENCE_NUMBER  \
# 11568  2021-09-14                Y        003F              37
# 23309  2021-09-14                Y        001F              39
# 26768  2021-09-14                Y        026C              20
# 31350  2021-09-14                Y        026C              20
# 32269  2021-09-14                Y        003C              31
#
#       PASSENGER_STATUS  AIRLINE_NUMERIC_CODE DOCUMENT_FORM_SN  \
# 11568                1                 487.0                0
# 23309                1                 487.0       0TT12G7B49
# 26768                3                 487.0       0YB2277034
# 31350                1                 487.0       0YB2277034
# 32269                1                 487.0                0
#
#        SELECTEE_INDICATOR  INTERNATIONAL_DOCUMENTATION_VERIFICATION  \
# 11568                 0.0                                       0.0
# 23309                 3.0                                       0.0
# 26768                 0.0                                       0.0
# 31350                 0.0                                       0.0
# 32269                 0.0                                       0.0
#
#       MARKETING_CARRIER_CODE  FREQUENT_FLYER_DESIGNATOR  \
# 11568                    NaN                        NaN
# 23309                    NaN                        NaN
# 26768                    NaN                        NaN
# 31350                    NaN                        NaN
# 32269                    NaN                        NaN
#
#        FREQUENT_FLYER_NUMBER  IDAD_INDICATOR FREE_BAGGAGE_ALLOWANCE  \
# 11568                    NaN             NaN                    NaN
# 23309                    NaN             NaN                    NaN
# 26768                    NaN             NaN                    NaN
# 31350                    NaN             NaN                    NaN
# 32269                    NaN             NaN                    NaN
#
#        FAST_TRACK      STAGING_TIMESTAMP2           dt_fl        Date  \
# 11568         NaN 2021-09-15 00:15:14.353  202109141357NK  2021-09-14
# 23309         NaN 2021-09-14 23:33:44.533  202109141357NK  2021-09-14
# 26768         NaN 2021-09-14 23:06:17.930  202109141357NK  2021-09-14
# 31350         NaN 2021-09-14 23:02:12.633  202109141357NK  2021-09-14
# 32269         NaN 2021-09-14 17:32:03.870  202109141357NK  2021-09-14
#
#       Military Time Flight Direction PA Airport Code   Terminal Desc  \
# 11568      20:05:00        Departure             EWR  EWR-Terminal B
# 23309      20:05:00        Departure             EWR  EWR-Terminal B
# 26768      20:05:00        Departure             EWR  EWR-Terminal B
# 31350      20:05:00        Departure             EWR  EWR-Terminal B
# 32269      20:05:00        Departure             EWR  EWR-Terminal B
#
#       Non-PA Airport Code Non-PA Airport Country Desc International Domestic  \
# 11568                 BOS                         USA               Domestic
# 23309                 BOS                         USA               Domestic
# 26768                 BOS                         USA               Domestic
# 31350                 BOS                         USA               Domestic
# 32269                 BOS                         USA               Domestic
#
#           State Desc Marketing Airline Desc Marketing Airline ICAO Code_x  \
# 11568  Massachusetts        Spirit Airlines                           NKS
# 23309  Massachusetts        Spirit Airlines                           NKS
# 26768  Massachusetts        Spirit Airlines                           NKS
# 31350  Massachusetts        Spirit Airlines                           NKS
# 32269  Massachusetts        Spirit Airlines                           NKS
#
#       Operating Airline Desc Operating Airline ICAO Code Flight Number  \
# 11568        Spirit Airlines                         NKS          1357
# 23309        Spirit Airlines                         NKS          1357
# 26768        Spirit Airlines                         NKS          1357
# 31350        Spirit Airlines                         NKS          1357
# 32269        Spirit Airlines                         NKS          1357
#
#          General Aircraft Desc    Variant Aircraft Desc Variant Aircraft Code  \
# 11568  Airbus A318/319/320/321  Airbus A320 (Sharklets)                   32A
# 23309  Airbus A318/319/320/321  Airbus A320 (Sharklets)                   32A
# 26768  Airbus A318/319/320/321  Airbus A320 (Sharklets)                   32A
# 31350  Airbus A318/319/320/321  Airbus A320 (Sharklets)                   32A
# 32269  Airbus A318/319/320/321  Airbus A320 (Sharklets)                   32A
#
#        Total Seats  Flight Distance  Total Flights                datt  month  \
# 11568        182.0            200.0            1.0 2021-09-14 20:05:00    9.0
# 23309        182.0            200.0            1.0 2021-09-14 20:05:00    9.0
# 26768        182.0            200.0            1.0 2021-09-14 20:05:00    9.0
# 31350        182.0            200.0            1.0 2021-09-14 20:05:00    9.0
# 32269        182.0            200.0            1.0 2021-09-14 20:05:00    9.0
#
#          year OpAL_IATACode OpAL_ICAOCode _merge
# 11568  2021.0            NK           NKS   both
# 23309  2021.0            NK           NKS   both
# 26768  2021.0            NK           NKS   both
# 31350  2021.0            NK           NKS   both
# 32269  2021.0            NK           NKS   both

# %%
nk1357.shape
# Out:
# (23, 55)

# %%
nk1357.LOCATION_POINT.value_counts()
# Out:
# 1    23
# Name: LOCATION_POINT, dtype: int64
